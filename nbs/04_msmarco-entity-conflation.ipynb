# %%
#| default_exp 04_msmarco-entity-conflation

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import scipy.sparse as sp, numpy as np
from tqdm.auto import tqdm
from termcolor import colored, COLORS
from scipy.sparse.csgraph import connected_components

from xcai.main import *
from xcai.data import XCDataset
from xcai.analysis import *

import xclib.evaluation.xc_metrics as xc_metrics
from xclib.utils.sparse import retain_topk

# %% [markdown]
# ## Linker predictions

# %% [markdown]
# ### `LLaMA`

# %%
pkl_dir = '/scratch/scai/phd/aiz218323/datasets/processed/'
pkl_file = f'{pkl_dir}/mogicX/msmarco_data-entity-llama_distilbert-base-uncased_sxc_exact.joblib'

config_file = '/scratch/scai/phd/aiz218323/datasets/msmarco/XC/configs/entity_llama_exact.json'
config_key = 'data_entity-llama_exact'

block = build_block(pkl_file, config_file, use_sxc=True, config_key=config_key)
linker_block = block.linker_dset('ent_meta', remove_empty=False)

# %%
pred_dir = '/home/scai/phd/aiz218323/scratch/outputs/mogicX/01-msmarco-llama-entity-linker-002/predictions/'
pred_lbl = sp.load_npz(f'{pred_dir}/test_predictions_full.npz')

pred_block = get_pred_dset(retain_topk(pred_lbl, k=5), linker_block.test.dset)

disp = CompareDataset(XCDataset._initialize(linker_block.test.dset), pred_block, '1. ', '2. ')

# %%
metric = pointwise_eval(pred_lbl, linker_block.test.dset.data.data_lbl, topk=5)

# %%
idxs = np.argsort(np.ravel(metric.sum(axis=1)))[:-100-1:-1]
disp.show(idxs)
# Out:
# 1.  data_input_text : how much protein and iron does fish have
# 2.  data_input_text : how much protein and iron does fish have
# 1.  lbl2data_input_text : ['protein', 'iron', 'fish']
# 2.  lbl2data_input_text : ['protein', 'iron', 'fish', 'fish symbol', 'vitamin iron']
#
# 1.  data_input_text : how far is lake como to lugano switzerland
# 2.  data_input_text : how far is lake como to lugano switzerland
# 1.  lbl2data_input_text : ['lake como', 'lugano', 'switzerland']
# 2.  lbl2data_input_text : ['switzerland', 'lake', 'lake como', 'lake geneva', 'lugano']
#
# 1.  data_input_text : phone number for autozone in calhoun ga
# 2.  data_input_text : phone number for autozone in calhoun ga
# 1.  lbl2data_input_text : ['autozone', 'calhoun', 'ga']
# 2.  lbl2data_input_text : ['georgia', 'ga', 'calhoun county', 'autozone', 'calhoun']
#
# 1.  data_input_text : which ventricle of the heart has the thickest myocardium layer and why
# 2.  data_input_text : which ventricle of the heart has the thickest myocardium layer and why
# 1.  lbl2data_input_text : ['ventricle', 'heart', 'myocardium']
# 2.  lbl2data_input_text : ['heart', 'myocardium', 'ventricle', 'where the heart is', 'heart ventricle']
#
# 1.  data_input_text : what type of muscle contains actin and myosin
# 2.  data_input_text : what type of muscle contains actin and myosin
# 1.  lbl2data_input_text : ['muscle', 'actin', 'myosin']
# 2.  lbl2data_input_text : ['muscle', 'myosin filaments', 'actin', 'myosin', 'myosin head']
#
# 1.  data_input_text : do physicians pay for insurance from their salaries?
# 2.  data_input_text : do physicians pay for insurance from their salaries?
# 1.  lbl2data_input_text : ['physicians', 'insurance', 'salaries']
# 2.  lbl2data_input_text : ['insurance', 'physicians', 'salaries', 'physician', 'medical insurance']
#
# 1.  data_input_text : what county is ridgway pa in
# 2.  data_input_text : what county is ridgway pa in
# 1.  lbl2data_input_text : ['ridgway', 'pa', 'county']
# 2.  lbl2data_input_text : ['county', 'pa', 'pennsylvania', 'pa.', 'ridgway']
#
# 1.  data_input_text : what county is beloit, wi in
# 2.  data_input_text : what county is beloit, wi in
# 1.  lbl2data_input_text : ['beloit', 'wi', 'county']
# 2.  lbl2data_input_text : ['county', 'wi', 'beloit', 'beloit college', 'beloit, wisconsin']
#
# 1.  data_input_text : lockheed martin field engineer salary
# 2.  data_input_text : lockheed martin field engineer salary
# 1.  lbl2data_input_text : ['lockheed martin', 'field engineer', 'salary']
# 2.  lbl2data_input_text : ['salary', 'salaries', 'lockheed martin', 'field engineer', 'lockheed']
#
# 1.  data_input_text : roselle nj what county
# 2.  data_input_text : roselle nj what county
# 1.  lbl2data_input_text : ['roselle', 'new jersey', 'county']
# 2.  lbl2data_input_text : ['county', 'nj', 'new jersey', 'roselle', 'roselle plant']
#
# 1.  data_input_text : where is ravenscroft, cheshire england?
# 2.  data_input_text : where is ravenscroft, cheshire england?
# 1.  lbl2data_input_text : ['ravenscroft', 'cheshire', 'england']
# 2.  lbl2data_input_text : ['england', 'cheshire', 'england and wales', 'foxcroft', 'ravenscroft']
#
# 1.  data_input_text : unemployment rate honolulu hawaii
# 2.  data_input_text : unemployment rate honolulu hawaii
# 1.  lbl2data_input_text : ['honolulu', 'hawaii', 'unemployment rate']
# 2.  lbl2data_input_text : ['honolulu', 'hawaii', 'unemployment rate', 'unemployment rates', 'honolulu, hawaii']
#
# 1.  data_input_text : what county is emmett ks in
# 2.  data_input_text : what county is emmett ks in
# 1.  lbl2data_input_text : ['emmett', 'ks', 'county']
# 2.  lbl2data_input_text : ['county', 'ks', 'emmett', 'emmett cullen', 'sedgwick county, ks']
#
# 1.  data_input_text : what causes bloating ,high blood pressure, and constipation
# 2.  data_input_text : what causes bloating ,high blood pressure, and constipation
# 1.  lbl2data_input_text : ['bloating', 'high blood pressure', 'constipation']
# 2.  lbl2data_input_text : ['constipation', 'bloating', 'high blood pressure', 'low blood pressure', 'obstipation']
#
# 1.  data_input_text : what county is oldsmar, fl in
# 2.  data_input_text : what county is oldsmar, fl in
# 1.  lbl2data_input_text : ['oldsmar', 'fl', 'county']
# 2.  lbl2data_input_text : ['county', 'fl', 'fl.', 'oldsmar', 'st johns county, florida']
#
# 1.  data_input_text : what is the climate of china in july and august
# 2.  data_input_text : what is the climate of china in july and august
# 1.  lbl2data_input_text : ['china', 'july', 'august']
# 2.  lbl2data_input_text : ['china', 'august', 'july', 'july and august', 'august 1']
#
# 1.  data_input_text : what time zone is tallahassee florida
# 2.  data_input_text : what time zone is tallahassee florida
# 1.  lbl2data_input_text : ['tallahassee', 'florida', 'time zone']
# 2.  lbl2data_input_text : ['florida', 'tallahassee', 'time zone', 'tallahassee, florida', 'tallahassee airport']
#
# 1.  data_input_text : is methadone an mdma receptor agonist
# 2.  data_input_text : is methadone an mdma receptor agonist
# 1.  lbl2data_input_text : ['methadone', 'mdma', 'receptor agonist']
# 2.  lbl2data_input_text : ['methadone', 'agonist', 'mdma', 'mdro', 'receptor agonist']
#
# 1.  data_input_text : what movie does dumbledore fight voldemort in
# 2.  data_input_text : what movie does dumbledore fight voldemort in
# 1.  lbl2data_input_text : ['dumbledore', 'voldemort', 'movie']
# 2.  lbl2data_input_text : ['film', 'movie', 'dumbledore', 'films', 'voldemort']
#
# 1.  data_input_text : the amendment that ensures the defendant has the right to an attorney is the ____________ amendment.
# 2.  data_input_text : the amendment that ensures the defendant has the right to an attorney is the ____________ amendment.
# 1.  lbl2data_input_text : ['amendment', 'defendant', 'attorney']
# 2.  lbl2data_input_text : ['amendment', 'attorney', 'defendant', 'us attorney', 'united states attorney']
#
# 1.  data_input_text : what does an egg contribute to the embryo that a sperm does not contribute?
# 2.  data_input_text : what does an egg contribute to the embryo that a sperm does not contribute?
# 1.  lbl2data_input_text : ['egg', 'embryo', 'sperm']
# 2.  lbl2data_input_text : ['egg', 'sperm', 'embryo', 'egg donation', 'embryos']
#
# 1.  data_input_text : how many electrons and protons and neutrons in gold?
# 2.  data_input_text : how many electrons and protons and neutrons in gold?
# 1.  lbl2data_input_text : ['electrons', 'protons', 'neutrons', 'gold']
# 2.  lbl2data_input_text : ['gold', 'electrons', 'neutrons', 'gold ore', 'band of gold']
#
# 1.  data_input_text : when the northern hemisphere experiences summer, the southern hemisphere experiences
# 2.  data_input_text : when the northern hemisphere experiences summer, the southern hemisphere experiences
# 1.  lbl2data_input_text : ['northern hemisphere', 'summer', 'southern hemisphere']
# 2.  lbl2data_input_text : ['summer', 'northern hemisphere', 'southern hemisphere', 'summer temperature', 'south hemisphere']
#
# 1.  data_input_text : difference between scholarships grants loans
# 2.  data_input_text : difference between scholarships grants loans
# 1.  lbl2data_input_text : ['scholarships', 'grants', 'loans']
# 2.  lbl2data_input_text : ['grants', 'scholarship', 'loans', 'grant', 'scholarships']
#
# 1.  data_input_text : euless texas is in what county?
# 2.  data_input_text : euless texas is in what county?
# 1.  lbl2data_input_text : ['euless', 'texas', 'county']
# 2.  lbl2data_input_text : ['texas', 'county', 'state of texas', 'euless', 'texas state']
#
# 1.  data_input_text : how long will food last in the refrigerator without power
# 2.  data_input_text : how long will food last in the refrigerator without power
# 1.  lbl2data_input_text : ['food', 'refrigerator', 'power']
# 2.  lbl2data_input_text : ['fridge', 'food', 'refrigerator', 'power', 'refrigerators']
#
# 1.  data_input_text : how much is gas tax on gallon in florida
# 2.  data_input_text : how much is gas tax on gallon in florida
# 1.  lbl2data_input_text : ['gas tax', 'gallon', 'florida']
# 2.  lbl2data_input_text : ['florida', 'miles per gallon', 'gallon', 'gas tax', 'florida city gas']
#
# 1.  data_input_text : how long to cook sauerkraut and fresh kielbasa in slow cooker
# 2.  data_input_text : how long to cook sauerkraut and fresh kielbasa in slow cooker
# 1.  lbl2data_input_text : ['sauerkraut', 'kielbasa', 'slow cooker']
# 2.  lbl2data_input_text : ['sauerkraut', 'slow cooker', 'kiel', 'kielbasa', 'polish kielbasa']
#
# 1.  data_input_text : which organisms utilize a one-way air flow through their lungs to maximize air flow efficiency and oxygen consumption?
# 2.  data_input_text : which organisms utilize a one-way air flow through their lungs to maximize air flow efficiency and oxygen consumption?
# 1.  lbl2data_input_text : ['organisms', 'lungs', 'air flow']
# 2.  lbl2data_input_text : ['lungs', 'oxygen', 'organism', 'organisms', 'air flow']
#
# 1.  data_input_text : how many children are identified with autism according to the cdc
# 2.  data_input_text : how many children are identified with autism according to the cdc
# 1.  lbl2data_input_text : ['children', 'autism', 'cdc']
# 2.  lbl2data_input_text : ['children', 'cdc', 'autism', 'children with autism', 'autism disorder']
#
# 1.  data_input_text : are eggs or grapes better to fight colds
# 2.  data_input_text : are eggs or grapes better to fight colds
# 1.  lbl2data_input_text : ['eggs', 'grapes', 'colds']
# 2.  lbl2data_input_text : ['eggs', 'cold', 'colds', 'grapes', 'frozen grapes']
#
# 1.  data_input_text : is there a difference in mitosis between animal and plant cells?
# 2.  data_input_text : is there a difference in mitosis between animal and plant cells?
# 1.  lbl2data_input_text : ['mitosis', 'animal cells', 'plant cells']
# 2.  lbl2data_input_text : ['mitosis', 'plant cells', 'animal cells', 'plant cell', 'mitotic cells']
#
# 1.  data_input_text : gold price in ksa dammam
# 2.  data_input_text : gold price in ksa dammam
# 1.  lbl2data_input_text : ['gold', 'ksa', 'dammam']
# 2.  lbl2data_input_text : ['gold', 'ks', 'ksa', 'dammam', 'kansas, mo']
#
# 1.  data_input_text : what county is morrilton arkansas in
# 2.  data_input_text : what county is morrilton arkansas in
# 1.  lbl2data_input_text : ['morrilton', 'arkansas', 'county']
# 2.  lbl2data_input_text : ['county', 'arkansas', 'arkansas county', 'tipton county', 'morrilton']
#
# 1.  data_input_text : what county is homewood il in
# 2.  data_input_text : what county is homewood il in
# 1.  lbl2data_input_text : ['homewood', 'il', 'county']
# 2.  lbl2data_input_text : ['county', 'illinois', 'il', 'homewood', 'lake county, il']
#
# 1.  data_input_text : what is the curfew for minors in hawaii
# 2.  data_input_text : what is the curfew for minors in hawaii
# 1.  lbl2data_input_text : ['curfew', 'minors', 'hawaii']
# 2.  lbl2data_input_text : ['hawaii', 'minors', 'curfew', 'island of hawaii', 'honolulu, hawaii']
#
# 1.  data_input_text : whats the difference between a llc , s corp and c corp
# 2.  data_input_text : whats the difference between a llc , s corp and c corp
# 1.  lbl2data_input_text : ['llc', 's corp', 'c corp', 'llc', 's corp', 'c corp']
# 2.  lbl2data_input_text : ['c corporation', 'llc', 's corp', 'c corp', 'llcs']
#
# 1.  data_input_text : what are conchae or turbinates and what function do they do for breathing?
# 2.  data_input_text : what are conchae or turbinates and what function do they do for breathing?
# 1.  lbl2data_input_text : ['conchae', 'turbinates', 'breathing', 'conchae', 'turbinates', 'breathing']
# 2.  lbl2data_input_text : ['breathing', 'conchae', 'turbinate', 'nasal turbinates', 'turbinates']
#
# 1.  data_input_text : what county is janesville mn in
# 2.  data_input_text : what county is janesville mn in
# 1.  lbl2data_input_text : ['janesville', 'mn', 'county']
# 2.  lbl2data_input_text : ['county', 'mn', 'jane', 'janelle', 'janesville']
#
# 1.  data_input_text : what county is vanderpool tx in
# 2.  data_input_text : what county is vanderpool tx in
# 1.  lbl2data_input_text : ['vanderpool', 'tx', 'county']
# 2.  lbl2data_input_text : ['texas', 'county', 'tx', 'vanderpool', 'vanderburgh county']
#
# 1.  data_input_text : what's the movie with meryl streep that a dingo ate her baby
# 2.  data_input_text : what's the movie with meryl streep that a dingo ate her baby
# 1.  lbl2data_input_text : ['meryl streep', 'dingo', 'baby']
# 2.  lbl2data_input_text : ['baby', 'babies', 'meryl streep', 'dingo', 'dingos']
#
# 1.  data_input_text : what county is upper saddle river nj in
# 2.  data_input_text : what county is upper saddle river nj in
# 1.  lbl2data_input_text : ['upper saddle river', 'nj', 'county']
# 2.  lbl2data_input_text : ['county', 'nj', 'new jersey', 'upper saddle river', 'bergen county']
#
# 1.  data_input_text : what county is stacy minnesota
# 2.  data_input_text : what county is stacy minnesota
# 1.  lbl2data_input_text : ['stacy', 'minnesota', 'county']
# 2.  lbl2data_input_text : ['county', 'minnesota', 'stacy', 'stacy burke', 'stacy adams']
#
# 1.  data_input_text : what county is delphos ohio
# 2.  data_input_text : what county is delphos ohio
# 1.  lbl2data_input_text : ['delphos', 'ohio', 'county']
# 2.  lbl2data_input_text : ['county', 'ohio', 'delphos', 'mahoning county, oh', 'delos']
#
# 1.  data_input_text : what hormone stimulates the production of sperm gcse
# 2.  data_input_text : what hormone stimulates the production of sperm gcse
# 1.  lbl2data_input_text : ['hormone', 'sperm', 'gcse']
# 2.  lbl2data_input_text : ['hormone', 'sperm', 'gcse', 'sperms', 'sperm production']
#
# 1.  data_input_text : weather in copenhagen denmark in may
# 2.  data_input_text : weather in copenhagen denmark in may
# 1.  lbl2data_input_text : ['copenhagen', 'denmark', 'may']
# 2.  lbl2data_input_text : ['denmark', 'danish', 'copenhagen', 'may', 'may day']
#
# 1.  data_input_text : is the elliptical or treadmill better for burning fat
# 2.  data_input_text : is the elliptical or treadmill better for burning fat
# 1.  lbl2data_input_text : ['elliptical', 'treadmill', 'fat']
# 2.  lbl2data_input_text : ['fat', 'treadmill', 'elliptical', 'burning fat', 'fat burning']
#
# 1.  data_input_text : what county is lumberton, nc
# 2.  data_input_text : what county is lumberton, nc
# 1.  lbl2data_input_text : ['lumberton', 'nc', 'county']
# 2.  lbl2data_input_text : ['county', 'nc', 'lumberton', 'carolina', 'alamance county, nc']
#
# 1.  data_input_text : sandra bullock is she republican or democrat
# 2.  data_input_text : sandra bullock is she republican or democrat
# 1.  lbl2data_input_text : ['sandra bullock', 'republican', 'democrat']
# 2.  lbl2data_input_text : ['democrat', 'republican', 'democratic republican', 'sandra bullock', 'democratic republican party']
#
# 1.  data_input_text : what county is galva ks. in
# 2.  data_input_text : what county is galva ks. in
# 1.  lbl2data_input_text : ['galva', 'ks', 'county']
# 2.  lbl2data_input_text : ['county', 'ks', 'galva', 'galvan', 'galt, california']
#
# 1.  data_input_text : weather in malaga spain in april
# 2.  data_input_text : weather in malaga spain in april
# 1.  lbl2data_input_text : ['malaga', 'spain', 'april']
# 2.  lbl2data_input_text : ['april', 'spain', 'malaga', '16 april', 'valencia, spain']
#
# 1.  data_input_text : what is the interaction between surface water and groundwater in a watershed?
# 2.  data_input_text : what is the interaction between surface water and groundwater in a watershed?
# 1.  lbl2data_input_text : ['surface water', 'groundwater', 'watershed']
# 2.  lbl2data_input_text : ['watershed', 'groundwater', 'watersheds', 'surface water', 'groundwater flooding']
#
# 1.  data_input_text : what is inflammation of the mucous membranes of the bronchial tubes
# 2.  data_input_text : what is inflammation of the mucous membranes of the bronchial tubes
# 1.  lbl2data_input_text : ['inflammation', 'mucous membranes', 'bronchial tubes']
# 2.  lbl2data_input_text : ['mucous membranes', 'mucous membrane', 'bronchial tubes', 'bronchial tube inflammation', 'ciliated mucous membrane']
#
# 1.  data_input_text : generic blood thinners for afib
# 2.  data_input_text : generic blood thinners for afib
# 1.  lbl2data_input_text : ['blood thinners', 'afib']
# 2.  lbl2data_input_text : ['blood thinner', 'afib', 'generics', 'blood thinners', 'generic']
#
# 1.  data_input_text : how is gold used in science
# 2.  data_input_text : how is gold used in science
# 1.  lbl2data_input_text : ['gold', 'science']
# 2.  lbl2data_input_text : ['gold', 'science', 'earth science', 'scientific', 'sciences']
#
# 1.  data_input_text : how many atp does glycolysis produce
# 2.  data_input_text : how many atp does glycolysis produce
# 1.  lbl2data_input_text : ['atp', 'glycolysis', 'atp', 'glycolysis']
# 2.  lbl2data_input_text : ['atp', 'glycogenolysis', 'glycolysis', 'atp molecule', 'aerobic glycolysis']
#
# 1.  data_input_text : driving distance littleton co to ft. collins co
# 2.  data_input_text : driving distance littleton co to ft. collins co
# 1.  lbl2data_input_text : ['littleton', 'fort collins']
# 2.  lbl2data_input_text : ['fort collins', 'collins', 'fort collins, co', 'littleton', 'colorado state universityfort collins']
#
# 1.  data_input_text : what types of earthquake waves usually cause the most destruction?
# 2.  data_input_text : what types of earthquake waves usually cause the most destruction?
# 1.  lbl2data_input_text : ['earthquake', 'waves']
# 2.  lbl2data_input_text : ['waves', 'earthquake', 'seismic waves', 'seismic wave', 'earthquake waves']
#
# 1.  data_input_text : how much protein do i need women
# 2.  data_input_text : how much protein do i need women
# 1.  lbl2data_input_text : ['protein', 'women']
# 2.  lbl2data_input_text : ['protein', 'female', 'women', 'woman', 'i am woman']
#
# 1.  data_input_text : what is used to treat hiv/aids?
# 2.  data_input_text : what is used to treat hiv/aids?
# 1.  lbl2data_input_text : ['hiv', 'aids']
# 2.  lbl2data_input_text : ['hiv', 'aids', 'hiv/aids', 'hiv virus', 'hiv aids']
#
# 1.  data_input_text : when is biltmore decorated for christmas
# 2.  data_input_text : when is biltmore decorated for christmas
# 1.  lbl2data_input_text : ['biltmore', 'christmas']
# 2.  lbl2data_input_text : ['christmas', 'biltmore', 'biltmore estate', 'biltmore house', 'biltmore library']
#
# 1.  data_input_text : when ventricles in brain are widely spaced and no csp
# 2.  data_input_text : when ventricles in brain are widely spaced and no csp
# 1.  lbl2data_input_text : ['ventricles', 'brain', 'csp']
# 2.  lbl2data_input_text : ['brain', 'ventricles', 'right ventricle', 'ventricle', 'heart ventricle']
#
# 1.  data_input_text : what county is toledo oh in?
# 2.  data_input_text : what county is toledo oh in?
# 1.  lbl2data_input_text : ['toledo', 'ohio', 'county']
# 2.  lbl2data_input_text : ['ohio', 'toledo', 'toledo, oh', 'toledo, ohio', 'toledo, washington']
#
# 1.  data_input_text : why was napalm used in the vietnam war
# 2.  data_input_text : why was napalm used in the vietnam war
# 1.  lbl2data_input_text : ['napalm', 'vietnam war']
# 2.  lbl2data_input_text : ['vietnam', 'vietnam war', 'napalm', 'vietnam conflict', 'vietnam era']
#
# 1.  data_input_text : what is the score of the cavaliers and the warriors?
# 2.  data_input_text : what is the score of the cavaliers and the warriors?
# 1.  lbl2data_input_text : ['cavaliers', 'warriors']
# 2.  lbl2data_input_text : ['golden state warriors', 'cleveland cavaliers', 'warriors', 'cavaliers', 'the warriors']
#
# 1.  data_input_text : where did edison set up his first laboratory for research
# 2.  data_input_text : where did edison set up his first laboratory for research
# 1.  lbl2data_input_text : ['edison', 'laboratory']
# 2.  lbl2data_input_text : ['laboratory', 'thomas edison', 'edison', 'research laboratory', 'edison, nj']
#
# 1.  data_input_text : what blood stream messenger
# 2.  data_input_text : what blood stream messenger
# 1.  lbl2data_input_text : ['bloodstream', 'messenger']
# 2.  lbl2data_input_text : ['blood', 'bloodstream', 'blood stream', 'messenger', 'windows live messenger']
#
# 1.  data_input_text : which planet is colder saturn or neptune
# 2.  data_input_text : which planet is colder saturn or neptune
# 1.  lbl2data_input_text : ['saturn', 'neptune']
# 2.  lbl2data_input_text : ['planets', 'saturn', 'neptune', 'planet', 'planet neptune']
#
# 1.  data_input_text : how much does a bar of gold worth
# 2.  data_input_text : how much does a bar of gold worth
# 1.  lbl2data_input_text : ['bar of gold', 'gold']
# 2.  lbl2data_input_text : ['gold', 'bar cost', 'nothing gold can stay', 'bar of gold', 'gold bar']
#
# 1.  data_input_text : what is a great dane and mastiff
# 2.  data_input_text : what is a great dane and mastiff
# 1.  lbl2data_input_text : ['great dane', 'mastiff']
# 2.  lbl2data_input_text : ['great dane', 'mastiffs', 'mastiff', 'english mastiff', 'mastiff dog']
#
# 1.  data_input_text : how long does a mri of the knee take
# 2.  data_input_text : how long does a mri of the knee take
# 1.  lbl2data_input_text : ['mri', 'knee']
# 2.  lbl2data_input_text : ['knee', 'mri', 'mri scan', 'knee mri', 'mri scans']
#
# 1.  data_input_text : sulfate cas number
# 2.  data_input_text : sulfate cas number
# 1.  lbl2data_input_text : ['sulfate', 'cas number', 'sulfate', 'cas number', 'sulfate', 'cas number']
# 2.  lbl2data_input_text : ['cas number', 'cas', 'sulfate', 'lead sulfate', 'sulfates']
#
# 1.  data_input_text : is holland the netherlands
# 2.  data_input_text : is holland the netherlands
# 1.  lbl2data_input_text : ['holland', 'netherlands']
# 2.  lbl2data_input_text : ['netherlands', 'dutch', 'holland', 'kingdom of the netherlands', 'the netherlands']
#
# 1.  data_input_text : does estrogen make me start my period
# 2.  data_input_text : does estrogen make me start my period
# 1.  lbl2data_input_text : ['estrogen', 'period']
# 2.  lbl2data_input_text : ['estrogen blocker', 'period', 'estrogen', 'estrogen dominance', 'estrogens']
#
# 1.  data_input_text : how long does it take for collections to come off credit report
# 2.  data_input_text : how long does it take for collections to come off credit report
# 1.  lbl2data_input_text : ['collections', 'credit report']
# 2.  lbl2data_input_text : ['credit report', 'collections', 'credit reporting', 'credit reports', 'credit report company']
#
# 1.  data_input_text : what year did california girls-beach boys come out
# 2.  data_input_text : what year did california girls-beach boys come out
# 1.  lbl2data_input_text : ['california girls', 'beach boys', '1965']
# 2.  lbl2data_input_text : ['california', 'the beach boys', 'beach boys', 'california girls', 'beach boy']
#
# 1.  data_input_text : what is a phobia of life
# 2.  data_input_text : what is a phobia of life
# 1.  lbl2data_input_text : ['phobia', 'life']
# 2.  lbl2data_input_text : ['phobia', 'life', 'tree of life', 'phobias', 'phobic']
#
# 1.  data_input_text : what part of the eye allows light to enter
# 2.  data_input_text : what part of the eye allows light to enter
# 1.  lbl2data_input_text : ['eye', 'light']
# 2.  lbl2data_input_text : ['eye', 'lighting', 'light', 'lights', 'where the light gets in']
#
# 1.  data_input_text : what county is stafford tx
# 2.  data_input_text : what county is stafford tx
# 1.  lbl2data_input_text : ['stafford', 'tx', 'county', 'stafford', 'tx', 'county']
# 2.  lbl2data_input_text : ['texas', 'tx', 'stafford', 'stafford act', 'stafford county']
#
# 1.  data_input_text : average price of farmland nebraska
# 2.  data_input_text : average price of farmland nebraska
# 1.  lbl2data_input_text : ['nebraska', 'farmland']
# 2.  lbl2data_input_text : ['nebraska', 'omaha, ne', 'omaha, nebraska', 'omaha ne', 'farmland']
#
# 1.  data_input_text : weather in dresden august
# 2.  data_input_text : weather in dresden august
# 1.  lbl2data_input_text : ['dresden', 'august', 'dresden', 'august']
# 2.  lbl2data_input_text : ['august', 'august 2', 'july and august', 'august 1', 'dresden']
#
# 1.  data_input_text : cinnamon honey and lemon benefits
# 2.  data_input_text : cinnamon honey and lemon benefits
# 1.  lbl2data_input_text : ['cinnamon', 'honey', 'lemon']
# 2.  lbl2data_input_text : ['cinnamon', 'lemon', 'cinnamon tea', 'cinnamon trees', 'cinnamon whisky']
#
# 1.  data_input_text : windstream troubleshooting phone number
# 2.  data_input_text : windstream troubleshooting phone number
# 1.  lbl2data_input_text : ['windstream', 'phone number']
# 2.  lbl2data_input_text : ['phone number', 'contact number', 'telephone number', 'telephone numbers', 'windstream']
#
# 1.  data_input_text : what is a cabinet in govt
# 2.  data_input_text : what is a cabinet in govt
# 1.  lbl2data_input_text : ['cabinet', 'govt']
# 2.  lbl2data_input_text : ['cabinets', 'cabinet', 'govt', 'cabinet department', 'under cabinet']
#
# 1.  data_input_text : weather in mazatlan mexico
# 2.  data_input_text : weather in mazatlan mexico
# 1.  lbl2data_input_text : ['mazatlan', 'mexico']
# 2.  lbl2data_input_text : ['mexico', 'mauna loa', 'mazatlan', 'mauna kea', 'maza']
#
# 1.  data_input_text : was the great wall of china breached
# 2.  data_input_text : was the great wall of china breached
# 1.  lbl2data_input_text : ['great wall of china', 'china']
# 2.  lbl2data_input_text : ['china', 'great wall of china', 'curtain wall', 'great wall', 'wall of china']
#
# 1.  data_input_text : how much to replace honda civic ignition switch
# 2.  data_input_text : how much to replace honda civic ignition switch
# 1.  lbl2data_input_text : ['honda civic', 'ignition switch']
# 2.  lbl2data_input_text : ['honda civic', 'honda civic ex', 'honda civic si', 'ignition switch', 'honda civic hybrid']
#
# 1.  data_input_text : what is a cyst on the kidneys do
# 2.  data_input_text : what is a cyst on the kidneys do
# 1.  lbl2data_input_text : ['cyst', 'kidneys', 'cyst', 'kidneys']
# 2.  lbl2data_input_text : ['kidneys', 'kidney', 'cyst', 'kidney cyst', 'kidney cysts']
#
# 1.  data_input_text : what causes the lower back to bruise over the kidneys
# 2.  data_input_text : what causes the lower back to bruise over the kidneys
# 1.  lbl2data_input_text : ['lower back', 'kidneys']
# 2.  lbl2data_input_text : ['kidneys', 'kidney', 'kidney damage', 'lower back', 'left kidney']
#
# 1.  data_input_text : most nigeria read newspaper
# 2.  data_input_text : most nigeria read newspaper
# 1.  lbl2data_input_text : ['nigeria', 'newspaper']
# 2.  lbl2data_input_text : ['newspaper', 'nigeria', 'nigerian president', 'nigerian', 'nigerian currency']
#
# 1.  data_input_text : what types of organisms go through fermentation?
# 2.  data_input_text : what types of organisms go through fermentation?
# 1.  lbl2data_input_text : ['fermentation', 'organisms']
# 2.  lbl2data_input_text : ['organisms', 'fermentation', 'fermentation process', 'yeast fermentation', 'all organisms']
#
# 1.  data_input_text : luggage that can withstand airline handling
# 2.  data_input_text : luggage that can withstand airline handling
# 1.  lbl2data_input_text : ['luggage', 'airline']
# 2.  lbl2data_input_text : ['airline', 'airline baggage handler', 'airline flight', 'luggage', 'us airline']
#
# 1.  data_input_text : do you need a transit visa for iran
# 2.  data_input_text : do you need a transit visa for iran
# 1.  lbl2data_input_text : ['transit visa', 'iran']
# 2.  lbl2data_input_text : ['iran', 'iranian', 'transit', 'transit visa', 'iranians']
#
# 1.  data_input_text : what is a phalanx in ancient greece?
# 2.  data_input_text : what is a phalanx in ancient greece?
# 1.  lbl2data_input_text : ['phalanx', 'ancient greece']
# 2.  lbl2data_input_text : ['pharynx', 'ancient greece', 'ancient greek', 'phalanx', 'ancient greek art']
#
# 1.  data_input_text : where is university of bridgeport located
# 2.  data_input_text : where is university of bridgeport located
# 1.  lbl2data_input_text : ['university of bridgeport', 'bridgeport']
# 2.  lbl2data_input_text : ['bridgeport', 'university of bridgeport', 'university of connecticut', 'bridgeport tx', 'university of hartford']
#
# 1.  data_input_text : which philosopher believed that only philosophers were capable of governing societies?
# 2.  data_input_text : which philosopher believed that only philosophers were capable of governing societies?
# 1.  lbl2data_input_text : ['philosopher', 'societies']
# 2.  lbl2data_input_text : ['philosopher', 'greek philosopher', 'greek philosophers', 'societies', 'philosophers']
#
# 1.  data_input_text : who is statesboro new football coach
# 2.  data_input_text : who is statesboro new football coach
# 1.  lbl2data_input_text : ['statesboro', 'football coach']
# 2.  lbl2data_input_text : ['football coaches', 'statesboro', 'head football coach', 'college football coach', 'football coach']
#
# 1.  data_input_text : how much apple cider vinegar is needed to help clear sinus
# 2.  data_input_text : how much apple cider vinegar is needed to help clear sinus
# 1.  lbl2data_input_text : ['apple cider vinegar', 'sinus']
# 2.  lbl2data_input_text : ['cider vinegar', 'apple cider vinegar', 'sinus', 'apple cider', 'apple vinegar']
#
# 1.  data_input_text : are snails good for plants
# 2.  data_input_text : are snails good for plants
# 1.  lbl2data_input_text : ['snails', 'plants']
# 2.  lbl2data_input_text : ['plant', 'plants', 'snail', 'snails', 'plant species']
#
# 1.  data_input_text : when to stop turning eggs in incubator
# 2.  data_input_text : when to stop turning eggs in incubator
# 1.  lbl2data_input_text : ['eggs', 'incubator', 'eggs', 'incubator']
# 2.  lbl2data_input_text : ['eggs', 'egg', 'incubator', 'egg incubator', 'incubators']

# %%
idxs = np.argsort(np.ravel(metric.sum(axis=1)))[:100]
disp.show(idxs)
# Out:
# 1.  data_input_text : blood diseases that are sexually transmitted
# 2.  data_input_text : blood diseases that are sexually transmitted
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['sexually transmitted disease', 'sexually transmitted', 'sexually transmitted diseases', 'bacterial sexually transmitted disease', 'sexual transmitted diseases']
#
# 1.  data_input_text : define bona fides
# 2.  data_input_text : define bona fides
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['bona fide', 'fides', 'bona', 'bona fide need rule', 'bona fide needs rule']
#
# 1.  data_input_text : effects of detox juice cleanse
# 2.  data_input_text : effects of detox juice cleanse
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['detoxing', 'detox', 'detox diet', 'juice cleanse', 'detox drinks']
#
# 1.  data_input_text : causes of petechial hemorrhage
# 2.  data_input_text : causes of petechial hemorrhage
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['petechiae', 'hemorrhages', 'hemorrhage', 'subconjunctival hemorrhage', 'bronchial hemorrhage']
#
# 1.  data_input_text : how long does it take to get your bsrn if you already have a bachelors degree
# 2.  data_input_text : how long does it take to get your bsrn if you already have a bachelors degree
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['bachelors degree', "bachelor's degree", 'bachelor degree', 'bsn degree', 'bachelors degrees']
#
# 1.  data_input_text : does contraction of the ciliary muscles shorten the lens
# 2.  data_input_text : does contraction of the ciliary muscles shorten the lens
# 1.  lbl2data_input_text : ['lens']
# 2.  lbl2data_input_text : ['ciliary muscle', 'long ciliary nerve', 'ciliary body', 'ciliary function', 'ciliary nerve']
#
# 1.  data_input_text : do spiders eat other animals
# 2.  data_input_text : do spiders eat other animals
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['spider', 'animals', 'spiders', 'spider monkey', 'fear of spiders']
#
# 1.  data_input_text : how to play blu ray discs
# 2.  data_input_text : how to play blu ray discs
# 1.  lbl2data_input_text : ['bluray discs']
# 2.  lbl2data_input_text : ['disc', 'discs', 'rays', 'ray', 'dvd disc']
#
# 1.  data_input_text : define retrogressed
# 2.  data_input_text : define retrogressed
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['progreso', 'retro', 'egress', 'egress windows', 'retrogradation']
#
# 1.  data_input_text : how many players on a women's lacrosse team
# 2.  data_input_text : how many players on a women's lacrosse team
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['college lacrosse team', 'lacrosse', "women's football players", "women's teams", 'lacrosse team']
#
# 1.  data_input_text : how long is mount beacon
# 2.  data_input_text : how long is mount beacon
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['beacon', 'mount baker', 'mount zion', 'mount olive', 'beacons']
#
# 1.  data_input_text : how long do you bake muffins
# 2.  data_input_text : how long do you bake muffins
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['muffins', 'muffin', 'mini muffins', 'muffin pan', 'muffin tins']
#
# 1.  data_input_text : ____________________ is considered the father of modern medicine.
# 2.  data_input_text : ____________________ is considered the father of modern medicine.
# 1.  lbl2data_input_text : ['hippocrates']
# 2.  lbl2data_input_text : ['medicine', 'modern', 'modern world', 'doctor of medicine', '__________']
#
# 1.  data_input_text : does xpress bet charge to deposit money in your account
# 2.  data_input_text : does xpress bet charge to deposit money in your account
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['us xpress', 'deposit account', 'xpress dating', 'xpress pay', 'xperia']
#
# 1.  data_input_text : botulinum definition
# 2.  data_input_text : botulinum definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['botulism', 'clostridium botulinum', 'botulinum toxin', 'bot', 'botulinium toxin']
#
# 1.  data_input_text : here there be dragons comic
# 2.  data_input_text : here there be dragons comic
# 1.  lbl2data_input_text : ['starchild']
# 2.  lbl2data_input_text : ['comic', 'dragon', 'comics', 'dragons', 'imagine dragons']
#
# 1.  data_input_text : how popular is the name kaitlyn
# 2.  data_input_text : how popular is the name kaitlyn
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['kaitlyn', 'chloe', 'kaitlyn jenner', 'popular music', 'name']
#
# 1.  data_input_text : effects hot stone has on the circulatory system
# 2.  data_input_text : effects hot stone has on the circulatory system
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['circulatory system', 'open circulatory system', 'closed circulatory system', 'circulatory', 'hot stone massage']
#
# 1.  data_input_text : how long is the bachelor finale
# 2.  data_input_text : how long is the bachelor finale
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['season finale', 'bachelor', 'series finale', 'the bachelor', 'tv finale']
#
# 1.  data_input_text : how long is the chinese wall
# 2.  data_input_text : how long is the chinese wall
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['chinese', 'the wall', 'great wall of china', 'wall of china', 'wall chinese restaurant']
#
# 1.  data_input_text : avg cost comercial grade carpet
# 2.  data_input_text : avg cost comercial grade carpet
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['carpet', 'wall to wall carpet', 'carpeting', 'builder grade carpet', 'carpet installation cost']
#
# 1.  data_input_text : cost analysis of school based obesity prevention program
# 2.  data_input_text : cost analysis of school based obesity prevention program
# 1.  lbl2data_input_text : ['canada']
# 2.  lbl2data_input_text : ['obesity', 'child obesity', 'obesity epidemic', 'obesity rate', 'normal weight obesity']
#
# 1.  data_input_text : calculate total days between two dates
# 2.  data_input_text : calculate total days between two dates
# 1.  lbl2data_input_text : ['days', 'b1', 'b2']
# 2.  lbl2data_input_text : ['date', 'dates', 'use by date', 'year to date', 'date format']
#
# 1.  data_input_text : how much is tuition at msu
# 2.  data_input_text : how much is tuition at msu
# 1.  lbl2data_input_text : ['michigan state university']
# 2.  lbl2data_input_text : ['tuition cost', 'tuition', 'msu', 'university of ms', 'ms degree']
#
# 1.  data_input_text : define: portrait
# 2.  data_input_text : define: portrait
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['portrait', 'meaning', 'portrait style', 'portrait photography', 'portraits']
#
# 1.  data_input_text : bash meanong
# 2.  data_input_text : bash meanong
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['basher', 'bashment', 'bash', 'bash shell', '.bash']
#
# 1.  data_input_text : do i really need to separate baby clothes by color before washing?
# 2.  data_input_text : do i really need to separate baby clothes by color before washing?
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['clothes', 'clothing', 'clothes washer', 'car wash', 'wash']
#
# 1.  data_input_text : definition of invariant
# 2.  data_input_text : definition of invariant
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['operational definition', 'meaning', 'mean', 'meanings', 'legal definition']
#
# 1.  data_input_text : how old to drink in iowa
# 2.  data_input_text : how old to drink in iowa
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['iowa', 'iowa state', 'iowa county', 'iowa score', 'ames, iowa']
#
# 1.  data_input_text : curious definition synonyms
# 2.  data_input_text : curious definition synonyms
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['meaning', 'mean', 'meanings', 'synonym', 'legal definition']
#
# 1.  data_input_text : eradicated definition
# 2.  data_input_text : eradicated definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['adjudicated property', 'adjudication', 'meaning', 'meanings', 'legal definition']
#
# 1.  data_input_text : age not to take off shoes at airline security
# 2.  data_input_text : age not to take off shoes at airline security
# 1.  lbl2data_input_text : ['age', 'age']
# 2.  lbl2data_input_text : ['airline', 'airline tickets', 'airline seats', 'airline ticket', 'us airline']
#
# 1.  data_input_text : cours definition
# 2.  data_input_text : cours definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['cours pr̩paratoire', 'cors', 'cor', 'cous cous', 'coir']
#
# 1.  data_input_text : streptococcus is a member of what group of organisms
# 2.  data_input_text : streptococcus is a member of what group of organisms
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['streptococcus pneumoniae', 'streptococcus', 'streptococcus infection', 'group a streptococcus', 'streptococcus agalactiae']
#
# 1.  data_input_text : average dimension of a shower stall
# 2.  data_input_text : average dimension of a shower stall
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['shower', 'toilet stall', 'shower seat', 'stall', 'stall shower']
#
# 1.  data_input_text : definition of purse
# 2.  data_input_text : definition of purse
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['purse', 'purses', 'meaning', 'mean', 'meanings']
#
# 1.  data_input_text : do david tate shoes run true to size
# 2.  data_input_text : do david tate shoes run true to size
# 1.  lbl2data_input_text : ['shoes']
# 2.  lbl2data_input_text : ['size', 'tate county', 'tater tot', 'dave tate', 'foot size']
#
# 1.  data_input_text : how to become a clnc?
# 2.  data_input_text : how to become a clnc?
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['cl', 'pnc', 'gnc', 'nnc', 'hnc']
#
# 1.  data_input_text : bondsman definition
# 2.  data_input_text : bondsman definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['bondservant', 'bond', 'bonds', 'harriet tubman', 'bail bondsman']
#
# 1.  data_input_text : stags meaning
# 2.  data_input_text : stags meaning
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['stag', 'meaning', 'stig', 'stagger', 'meanings']
#
# 1.  data_input_text : sterility meaning
# 2.  data_input_text : sterility meaning
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['sterilant', 'hybrid sterility', 'sterility', 'sterilization', 'sterilisation']
#
# 1.  data_input_text : how did the uluru rock form
# 2.  data_input_text : how did the uluru rock form
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['ulo', 'uluru national park', 'uluru', 'ultron', 'uhuru']
#
# 1.  data_input_text : how a fire tornado forms
# 2.  data_input_text : how a fire tornado forms
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['tornado', 'fire', 'fire tornadoes', 'fire tornado', 'fire type']
#
# 1.  data_input_text : calories in a flour wrap
# 2.  data_input_text : calories in a flour wrap
# 1.  lbl2data_input_text : ['calories']
# 2.  lbl2data_input_text : ['flour', 'all purpose flour', 'flourite', 'flourtown', 'flours']
#
# 1.  data_input_text : how many square kilometers is scotland's
# 2.  data_input_text : how many square kilometers is scotland's
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['scotland', 'scottish', 'square kilometers', 'scotland county', 'scots']
#
# 1.  data_input_text : cost estimation technique
# 2.  data_input_text : cost estimation technique
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['cost estimate', 'cost analyst', 'cost estimation', 'cost analysis', 'cost estimates']
#
# 1.  data_input_text : how  to prepare ground lamb
# 2.  data_input_text : how  to prepare ground lamb
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['ground beef', 'lamb', 'roast lamb', 'ground chicken', 'roast of lamb']
#
# 1.  data_input_text : strategery definition
# 2.  data_input_text : strategery definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['sty', 'stratum', 'edward stratemeyer', 'stratus', 'strategist']
#
# 1.  data_input_text : synonyms of ignorant
# 2.  data_input_text : synonyms of ignorant
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['meaning', 'ignorance', 'meanings', 'synonym', 'ignorant']
#
# 1.  data_input_text : honesty or integrity definition
# 2.  data_input_text : honesty or integrity definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['integrity', 'honesty', 'meaning', 'honesty day', 'meanings']
#
# 1.  data_input_text : how old is lil moco
# 2.  data_input_text : how old is lil moco
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['loco moco', 'moca', 'moz', 'year old', 'years old']
#
# 1.  data_input_text : systemic response definition
# 2.  data_input_text : systemic response definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['response', 'systemic shock', 'systemic disease', 'systemic allergic reaction', 'systemic symptoms']
#
# 1.  data_input_text : tangle definition
# 2.  data_input_text : tangle definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['meaning', 'tanglewood', 'meanings', 'tangled', 'legal definition']
#
# 1.  data_input_text : task definition
# 2.  data_input_text : task definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['task group', 'task host', 'meaning', 'tasks', 'task']
#
# 1.  data_input_text : how many words make up a page
# 2.  data_input_text : how many words make up a page
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['page', 'page number', 'pages document', 'pages', 'page numbers']
#
# 1.  data_input_text : stellar lumens price forecast
# 2.  data_input_text : stellar lumens price forecast
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['lumens', 'lumen', 'weather forecast', 'forecast', 'lumen diameter']
#
# 1.  data_input_text : circulation money definition
# 2.  data_input_text : circulation money definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['money', 'us currency', 'circulation', 'circulation problems', 'us money']
#
# 1.  data_input_text : define preventive
# 2.  data_input_text : define preventive
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['preventive medications', 'preventative maintenance', 'preventative care', 'meaning', 'preventive care']
#
# 1.  data_input_text : how big do newfypoo's get
# 2.  data_input_text : how big do newfypoo's get
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['new world', 'new washington', 'new account', 'new mexican', 'new windows']
#
# 1.  data_input_text : age requirements for name change
# 2.  data_input_text : age requirements for name change
# 1.  lbl2data_input_text : ['california', 'county', '18 years']
# 2.  lbl2data_input_text : ['name change token', 'name change', 'legal name change', 'legal name changes', 'age requirements']
#
# 1.  data_input_text : synonym of subordinate
# 2.  data_input_text : synonym of subordinate
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['subordinate clause', 'subordinated loan', 'subordinates', 'subordinate', 'synonym']
#
# 1.  data_input_text : define prosthetic device
# 2.  data_input_text : define prosthetic device
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['prosthetics', 'prosthetic valve', 'prosthetic', 'dental prosthetic', 'prosthetic devices']
#
# 1.  data_input_text : can seizure meds cause low sodium?
# 2.  data_input_text : can seizure meds cause low sodium?
# 1.  lbl2data_input_text : ['seizure', 'meds', 'sodium']
# 2.  lbl2data_input_text : ['low blood sodium levels', 'seizure disorder', 'seizure meds', 'seizure syndromes', 'seizure medication']
#
# 1.  data_input_text : synonyms for the word, decline
# 2.  data_input_text : synonyms for the word, decline
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['meaning', 'mean', 'meanings', 'antonym', 'synonym']
#
# 1.  data_input_text : what methodology is used for siemens rxl
# 2.  data_input_text : what methodology is used for siemens rxl
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['siemens', 'rls', 'siemens healthcare', 'methodology', 'werner von siemens']
#
# 1.  data_input_text : what is spredfast
# 2.  data_input_text : what is spredfast
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['spock', 'thredbo', 'spir', 'thredup', 'superfast']
#
# 1.  data_input_text : at what age does the average person retire
# 2.  data_input_text : at what age does the average person retire
# 1.  lbl2data_input_text : ['age', 'person']
# 2.  lbl2data_input_text : ['retirement age', 'retired person', 'retired people', 'retire', 'traditional age of retirement']
#
# 1.  data_input_text : did hector camacho died
# 2.  data_input_text : did hector camacho died
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['ariel camacho', 'muchacho', 'juan rodriguez cabrillo', 'hector', 'hector labo']
#
# 1.  data_input_text : definition of introspective.
# 2.  data_input_text : definition of introspective.
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['recollective', 'meaning', 'introspection', 'mean', 'meanings']
#
# 1.  data_input_text : calculate days past ovulation
# 2.  data_input_text : calculate days past ovulation
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['ovulation', 'ovulation day', 'ovulation date', 'ovulation period', 'ovulation calendar']
#
# 1.  data_input_text : average salary for primary care sports medicine doctors
# 2.  data_input_text : average salary for primary care sports medicine doctors
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['primary care doctor', 'sports medicine doctors', 'primary care physicians', 'primary care doctors', 'sports medicine doctor']
#
# 1.  data_input_text : argue the meaning of a debate
# 2.  data_input_text : argue the meaning of a debate
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['presidential debate', 'dispute', 'argument', 'debate team', 'debate']
#
# 1.  data_input_text : tire wear patterns and causes
# 2.  data_input_text : tire wear patterns and causes
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['tire', 'tire prices', 'tires', 'tire sizes', 'tire warranty']
#
# 1.  data_input_text : to what extent is exclusion ethical according to the nasw code of ethics?
# 2.  data_input_text : to what extent is exclusion ethical according to the nasw code of ethics?
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['code of ethics', 'exclusion', 'ethics', 'committee on ethics', 'ethics code']
#
# 1.  data_input_text : total number of cases argued per year to supreme court
# 2.  data_input_text : total number of cases argued per year to supreme court
# 1.  lbl2data_input_text : ['supreme court']
# 2.  lbl2data_input_text : ['us supreme court', 'united states supreme court', 'u.s. supreme court', 'u.s supreme court', 'supreme court of the united states']
#
# 1.  data_input_text : trailer hitches installed cost
# 2.  data_input_text : trailer hitches installed cost
# 1.  lbl2data_input_text : ['cost']
# 2.  lbl2data_input_text : ['trailer', 'trailer hitch', 'trailer lights', 'hitch', 'install cost']
#
# 1.  data_input_text : bula definition
# 2.  data_input_text : bula definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['bu', 'bla', 'marla', 'bula', 'pula']
#
# 1.  data_input_text : triads definition
# 2.  data_input_text : triads definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['triad cable', 'triad of services', 'triad', 'triads', 'triadic melody']
#
# 1.  data_input_text : tribals definition
# 2.  data_input_text : tribals definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['tribal society', 'tribes', 'tribal membership', 'tribesa', 'tribalism']
#
# 1.  data_input_text : trod meaning
# 2.  data_input_text : trod meaning
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['flod', 'eod', 'zod', 'arod', 'fod']
#
# 1.  data_input_text : sorcerer definition
# 2.  data_input_text : sorcerer definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ["harry potter and the sorcerer's stone", 'sorcerer mickey mouse', 'meaning', 'meanings', "sorcerer's apprentice"]
#
# 1.  data_input_text : britne oldford worth
# 2.  data_input_text : britne oldford worth
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['telford', 'richford', 'brita', 'britt', 'brit']
#
# 1.  data_input_text : the wellness collective
# 2.  data_input_text : the wellness collective
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['wellness center', 'collective', 'wellness entrepreneur', 'wellness', 'wellness centers']
#
# 1.  data_input_text : theory of transformational learning definition
# 2.  data_input_text : theory of transformational learning definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['observational learning', 'learning theory', 'learning', 'social learning theory', 'transformation']
#
# 1.  data_input_text : thrombopenia definition
# 2.  data_input_text : thrombopenia definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['thrombocytopenia', 'thromboembolism', 'thrombocytosis', 'thrombopoietin', 'thrombophilia']
#
# 1.  data_input_text : tim chapman net worth
# 2.  data_input_text : tim chapman net worth
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['chapman', 'tim williams', 'mike chapman', 'tim duncan', 'tim tam']
#
# 1.  data_input_text : time in yekaterinburg
# 2.  data_input_text : time in yekaterinburg
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['time', 'yelp', 'boris yeltsin', 'yelm, wa', 'harrodsburg, in']
#
# 1.  data_input_text : time to cut knock out roses
# 2.  data_input_text : time to cut knock out roses
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['roses', 'war of the roses', 'knock knockout roses', 'knock out roses', 'bed of roses']
#
# 1.  data_input_text : how long do you cook pork tenderloin in oven
# 2.  data_input_text : how long do you cook pork tenderloin in oven
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['pork tenderloin', 'pork tenderloin roast', 'pork loin tenderloin', 'pork tenderloins', 'roasted pork tenderloin']
#
# 1.  data_input_text : define enquires
# 2.  data_input_text : define enquires
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['inquirer', 'meaning', 'mean', 'meanings', 'legal definition']
#
# 1.  data_input_text : how soon together for epidural injections
# 2.  data_input_text : how soon together for epidural injections
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['epidural', 'epidural steroid injection', 'epidural space', 'epidurals', 'epidural shots']
#
# 1.  data_input_text : cooperative building definition
# 2.  data_input_text : cooperative building definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['cooperative', 'cooperative living', 'cooperative house', 'cooperative agreement', 'cooperative store']
#
# 1.  data_input_text : cause of painful swollen lymph nodes
# 2.  data_input_text : cause of painful swollen lymph nodes
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['lymph node', 'lymph nodes', 'lymph', 'lymph pain', 'abdominal lymph nodes']
#
# 1.  data_input_text : are concierge medical fees tax deductible
# 2.  data_input_text : are concierge medical fees tax deductible
# 1.  lbl2data_input_text : ['tax deductible']
# 2.  lbl2data_input_text : ['concierge business', 'concierge', 'concierge service', 'medical deductibles', 'medical concierge services']
#
# 1.  data_input_text : someone definition
# 2.  data_input_text : someone definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['person', 'who', 'someone', 'meaning', 'meanings']
#
# 1.  data_input_text : do french women play sports
# 2.  data_input_text : do french women play sports
# 1.  lbl2data_input_text : ['sports']
# 2.  lbl2data_input_text : ['france', 'french', 'french people', 'french city', 'french football federation']
#
# 1.  data_input_text : what is the dependent type
# 2.  data_input_text : what is the dependent type
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['dependent', 'dependent variable', 'dependents', 'dependent variables', 'type']
#
# 1.  data_input_text : when was the first known japanese animation produced?
# 2.  data_input_text : when was the first known japanese animation produced?
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['japan', 'japanese', 'japanese language', 'animation', 'first full length animated film']
#
# 1.  data_input_text : what is the difference in a c corp or s corp
# 2.  data_input_text : what is the difference in a c corp or s corp
# 1.  lbl2data_input_text : ['scorp', 'scorp']
# 2.  lbl2data_input_text : ['c corporation', 's corp', 's.c.', 'c:', 'c corp']
#
# 1.  data_input_text : contacts meaning
# 2.  data_input_text : contacts meaning
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['contacts', 'meaning', 'contact', 'mean', 'meanings']

# %% [markdown]
# ## `GPT`

# %%
pkl_dir = '/scratch/scai/phd/aiz218323/datasets/processed/'
pkl_file = f'{pkl_dir}/mogicX/msmarco_data-entity-gpt_distilbert-base-uncased_sxc_exact.joblib'

config_file = '/scratch/scai/phd/aiz218323/datasets/msmarco/XC/configs/entity_gpt_exact.json'
config_key = 'data_entity-gpt_exact'

block = build_block(pkl_file, config_file, use_sxc=True, config_key=config_key)
linker_block = block.linker_dset('ent_meta', remove_empty=False)

# %%
pred_dir = '/home/scai/phd/aiz218323/scratch/outputs/mogicX/01-msmarco-gpt-entity-linker-001/predictions/'
pred_lbl = sp.load_npz(f'{pred_dir}/test_predictions_full.npz')

pred_block = get_pred_dset(retain_topk(pred_lbl, k=5), linker_block.test.dset)

disp = CompareDataset(XCDataset._initialize(linker_block.test.dset), pred_block, '1. ', '2. ')

# %%
metric = pointwise_eval(pred_lbl, linker_block.test.dset.data.data_lbl, topk=5)

# %%
idxs = np.argsort(np.ravel(metric.sum(axis=1)))[:-100-1:-1]
disp.show(idxs)
# Out:
# 1.  data_input_text : does adult acne rosacea give you blepharitis
# 2.  data_input_text : does adult acne rosacea give you blepharitis
# 1.  lbl2data_input_text : ['adult acne', 'rosacea', 'blepharitis']
# 2.  lbl2data_input_text : ['blepharitis', 'rosacea', 'skin rosacea', 'acne vulgaris', 'adult acne']
#
# 1.  data_input_text : how much protein and iron does fish have
# 2.  data_input_text : how much protein and iron does fish have
# 1.  lbl2data_input_text : ['protein', 'iron', 'fish']
# 2.  lbl2data_input_text : ['fish', 'iron', 'protein', 'vitamin iron', 'fish diet']
#
# 1.  data_input_text : where does qatar fly
# 2.  data_input_text : where does qatar fly
# 1.  lbl2data_input_text : ['qatar', 'qatar airways', 'doha']
# 2.  lbl2data_input_text : ['doha', 'qatar', 'qatar airways', 'qatar international airport', 'doha airport']
#
# 1.  data_input_text : what federal statute gives the epa authority to regulate pesticides
# 2.  data_input_text : what federal statute gives the epa authority to regulate pesticides
# 1.  lbl2data_input_text : ['federal statute', 'epa', 'pesticides']
# 2.  lbl2data_input_text : ['epa', 'pesticides', 'federal statute', 'federal regulation', 'us epa']
#
# 1.  data_input_text : when the northern hemisphere experiences summer, the southern hemisphere experiences
# 2.  data_input_text : when the northern hemisphere experiences summer, the southern hemisphere experiences
# 1.  lbl2data_input_text : ['northern hemisphere', 'southern hemisphere', 'summer']
# 2.  lbl2data_input_text : ['northern hemisphere', 'summer', 'southern hemisphere', 'western hemisphere', 'south hemisphere']
#
# 1.  data_input_text : what county is vanderpool tx in
# 2.  data_input_text : what county is vanderpool tx in
# 1.  lbl2data_input_text : ['vanderpool', 'texas', 'county']
# 2.  lbl2data_input_text : ['county', 'texas', 'texas association of counties', 'vanderpool', 'vanderburgh county']
#
# 1.  data_input_text : whats the difference between a llc , s corp and c corp
# 2.  data_input_text : whats the difference between a llc , s corp and c corp
# 1.  lbl2data_input_text : ['llc', 's corp', 'c corp', 'llc', 's corp', 'c corp']
# 2.  lbl2data_input_text : ['llc', 's corp', 'c corp', 'c corporation', 'llcs']
#
# 1.  data_input_text : lewiston idaho fedex express phone number
# 2.  data_input_text : lewiston idaho fedex express phone number
# 1.  lbl2data_input_text : ['lewiston', 'idaho', 'fedex express']
# 2.  lbl2data_input_text : ['idaho', 'lewiston', 'boise, idaho', "coeur d'alene, idaho", 'fedex express']
#
# 1.  data_input_text : what time zone is crown point, indiana in
# 2.  data_input_text : what time zone is crown point, indiana in
# 1.  lbl2data_input_text : ['crown point', 'indiana', 'time zone']
# 2.  lbl2data_input_text : ['central time zone', 'indiana', 'time zone', 'crown point', 'crown point, indiana']
#
# 1.  data_input_text : difference between scholarships grants loans
# 2.  data_input_text : difference between scholarships grants loans
# 1.  lbl2data_input_text : ['scholarships', 'grants', 'loans']
# 2.  lbl2data_input_text : ['grants', 'loans', 'scholarship', 'scholarships', 'college scholarships']
#
# 1.  data_input_text : can vigamox eye drops cause nausea
# 2.  data_input_text : can vigamox eye drops cause nausea
# 1.  lbl2data_input_text : ['vigamox', 'eye drops', 'nausea']
# 2.  lbl2data_input_text : ['nausea', 'eye drops', 'vioxx', 'vigamox', 'anti nausea medication']
#
# 1.  data_input_text : what county is morrilton arkansas in
# 2.  data_input_text : what county is morrilton arkansas in
# 1.  lbl2data_input_text : ['morrilton', 'arkansas', 'county']
# 2.  lbl2data_input_text : ['county', 'arkansas', 'teton county', 'morrilton', 'tipton county']
#
# 1.  data_input_text : what county is upper saddle river nj in
# 2.  data_input_text : what county is upper saddle river nj in
# 1.  lbl2data_input_text : ['upper saddle river', 'bergen county', 'nj']
# 2.  lbl2data_input_text : ['nj', 'new jersey', 'upper saddle river', 'bergen county', 'edison, nj']
#
# 1.  data_input_text : what causes bloating ,high blood pressure, and constipation
# 2.  data_input_text : what causes bloating ,high blood pressure, and constipation
# 1.  lbl2data_input_text : ['bloating', 'high blood pressure', 'constipation']
# 2.  lbl2data_input_text : ['high blood pressure', 'constipation', 'bloating', 'opiate induced constipation', 'obstipation']
#
# 1.  data_input_text : is there a difference in mitosis between animal and plant cells?
# 2.  data_input_text : is there a difference in mitosis between animal and plant cells?
# 1.  lbl2data_input_text : ['mitosis', 'animal cells', 'plant cells', 'vitamin d']
# 2.  lbl2data_input_text : ['plant cells', 'animal cells', 'mitosis', 'cellular mitosis', 'mitotic cells']
#
# 1.  data_input_text : what does an egg contribute to the embryo that a sperm does not contribute?
# 2.  data_input_text : what does an egg contribute to the embryo that a sperm does not contribute?
# 1.  lbl2data_input_text : ['egg', 'embryo', 'sperm']
# 2.  lbl2data_input_text : ['egg', 'sperm', 'embryo', 'embryos', 'sperm donation']
#
# 1.  data_input_text : what happens to the volume of a sphere as the surface area increases?
# 2.  data_input_text : what happens to the volume of a sphere as the surface area increases?
# 1.  lbl2data_input_text : ['volume', 'sphere', 'surface area']
# 2.  lbl2data_input_text : ['surface area', 'volume', 'surface', 'sphere', 'surface area to volume ratio']
#
# 1.  data_input_text : ketamine withdrawal symptoms
# 2.  data_input_text : ketamine withdrawal symptoms
# 1.  lbl2data_input_text : ['ketamine', 'withdrawal symptoms', 'hip pain', 'mattress', 'spine']
# 2.  lbl2data_input_text : ['ketamine', 'withdrawal symptoms', 'acute withdrawal symptoms', 'caffeine withdrawal', 'ketamine infusion']
#
# 1.  data_input_text : how many oscars has peter jackson wolllnlll?l
# 2.  data_input_text : how many oscars has peter jackson wolllnlll?l
# 1.  lbl2data_input_text : ['oscars', 'peter jackson']
# 2.  lbl2data_input_text : ['oscars', 'peter jackson', 'oscar', 'oscar awards', 'the oscars']
#
# 1.  data_input_text : what type of fire extinguisher is best for electrical equipment
# 2.  data_input_text : what type of fire extinguisher is best for electrical equipment
# 1.  lbl2data_input_text : ['fire extinguisher', 'electrical equipment']
# 2.  lbl2data_input_text : ['fire extinguisher training', 'fire extinguisher', 'fire extinguishers', 'electrical equipment', 'portable fire extinguisher']
#
# 1.  data_input_text : what does btu stand for in diesel
# 2.  data_input_text : what does btu stand for in diesel
# 1.  lbl2data_input_text : ['btu', 'diesel']
# 2.  lbl2data_input_text : ['diesel', 'btu', 'btus', 'btu/h', 'btu/lb']
#
# 1.  data_input_text : what does penicillin treat in humans and animals
# 2.  data_input_text : what does penicillin treat in humans and animals
# 1.  lbl2data_input_text : ['penicillin', 'humans', 'animals']
# 2.  lbl2data_input_text : ['penicillin', 'humans', 'penicillin vk', 'penicillins', 'penicillin allergy']
#
# 1.  data_input_text : how much is the card reader through paypal
# 2.  data_input_text : how much is the card reader through paypal
# 1.  lbl2data_input_text : ['card reader', 'paypal']
# 2.  lbl2data_input_text : ['paypal', 'card readers', 'crind card reader', 'card reader', 'paypal credit']
#
# 1.  data_input_text : price of bath fitter for a tub
# 2.  data_input_text : price of bath fitter for a tub
# 1.  lbl2data_input_text : ['bath fitter', 'tub']
# 2.  lbl2data_input_text : ['tub', 'bath fitter', 'bath fitters', 'bath tub', 'bathroom fitters']
#
# 1.  data_input_text : how much is sprint restocking fee
# 2.  data_input_text : how much is sprint restocking fee
# 1.  lbl2data_input_text : ['sprint', 'restocking fee']
# 2.  lbl2data_input_text : ['sprint', 'sprinting', 'restocking fee', 'sprint corporation', 'hardening sprint']
#
# 1.  data_input_text : what nationality is male name ish
# 2.  data_input_text : what nationality is male name ish
# 1.  lbl2data_input_text : ['nationality', 'male', 'name']
# 2.  lbl2data_input_text : ['nationality', 'males', 'male', 'inh', 'black-ish']
#
# 1.  data_input_text : what cisco ios
# 2.  data_input_text : what cisco ios
# 1.  lbl2data_input_text : ['cisco ios', 'cisco systems']
# 2.  lbl2data_input_text : ['cisco', 'ios', 'cisco systems', 'cisco ise', 'cisco ios']
#
# 1.  data_input_text : medication administration closed system
# 2.  data_input_text : medication administration closed system
# 1.  lbl2data_input_text : ['medication administration', 'closed system']
# 2.  lbl2data_input_text : ['medication management', 'medication administration', 'closed system', 'medication administration program', 'medication administration system']
#
# 1.  data_input_text : how much is fireworks disney dessert
# 2.  data_input_text : how much is fireworks disney dessert
# 1.  lbl2data_input_text : ['disney', 'fireworks', 'dessert']
# 2.  lbl2data_input_text : ['disney', 'fireworks', 'disney magic', 'disney tickets', 'disney resort']
#
# 1.  data_input_text : how much is salt per cubic yard
# 2.  data_input_text : how much is salt per cubic yard
# 1.  lbl2data_input_text : ['salt', 'cubic yard']
# 2.  lbl2data_input_text : ['salt', 'cubic yard', 'cubic yards', '1 cubic yard', 'grain of salt']
#
# 1.  data_input_text : how much is gas tax on gallon in florida
# 2.  data_input_text : how much is gas tax on gallon in florida
# 1.  lbl2data_input_text : ['gas tax', 'gallon', 'florida']
# 2.  lbl2data_input_text : ['florida', 'gallon', 'state of florida', 'florida city gas', 'us gallon']
#
# 1.  data_input_text : different colors of sea urchin roe
# 2.  data_input_text : different colors of sea urchin roe
# 1.  lbl2data_input_text : ['sea urchin', 'roe']
# 2.  lbl2data_input_text : ['sea urchins', 'roe', 'sea urchin', 'purple sea urchins', 'urchin']
#
# 1.  data_input_text : distance phoenix to nogales
# 2.  data_input_text : distance phoenix to nogales
# 1.  lbl2data_input_text : ['phoenix', 'nogales']
# 2.  lbl2data_input_text : ['phoenix', 'phoenix, arizona', 'phoenix, az', 'nogales', 'nogales, az']
#
# 1.  data_input_text : what is the purpose of buttermilk in baking
# 2.  data_input_text : what is the purpose of buttermilk in baking
# 1.  lbl2data_input_text : ['buttermilk', 'baking']
# 2.  lbl2data_input_text : ['buttermilk', 'buttermilk powder', 'baking', 'bake', 'buttermilk bread']
#
# 1.  data_input_text : difference between sprain and strain
# 2.  data_input_text : difference between sprain and strain
# 1.  lbl2data_input_text : ['sprain', 'strain', 'sprain', 'strain']
# 2.  lbl2data_input_text : ['sprain', 'sprains', 's strain', 'the strain', 'strain']
#
# 1.  data_input_text : price to install door with frame
# 2.  data_input_text : price to install door with frame
# 1.  lbl2data_input_text : ['door', 'frame']
# 2.  lbl2data_input_text : ['frame', 'framing', 'door', 'door frame', 'frame construction']
#
# 1.  data_input_text : do leafy greens have iron
# 2.  data_input_text : do leafy greens have iron
# 1.  lbl2data_input_text : ['leafy greens', 'iron', 'leafy greens', 'iron']
# 2.  lbl2data_input_text : ['iron', 'leafy greens', 'dark leafy greens', 'greens', 'vitamin iron']
#
# 1.  data_input_text : how to change address for taxes
# 2.  data_input_text : how to change address for taxes
# 1.  lbl2data_input_text : ['address', 'taxes']
# 2.  lbl2data_input_text : ['taxes', 'postal address', 'address', 'change of address', 'addresses']
#
# 1.  data_input_text : causes of shaking and blurred vision
# 2.  data_input_text : causes of shaking and blurred vision
# 1.  lbl2data_input_text : ['shaking', 'blurred vision', 'shaking', 'blurred vision', 'shaking', 'blurred vision']
# 2.  lbl2data_input_text : ['blurred vision', 'blurry vision', 'head shaking', 'shaking', 'blurry eye vision']
#
# 1.  data_input_text : is coconut oil safe for cats
# 2.  data_input_text : is coconut oil safe for cats
# 1.  lbl2data_input_text : ['coconut oil', 'cats']
# 2.  lbl2data_input_text : ['cat', 'coconut oil', 'cats', 'pet cat', 'organic coconut oil']
#
# 1.  data_input_text : on what do biologists base their classification of organisms?
# 2.  data_input_text : on what do biologists base their classification of organisms?
# 1.  lbl2data_input_text : ['biologists', 'organisms', 'biologists', 'organisms']
# 2.  lbl2data_input_text : ['organisms', 'biologist', 'biologists', 'group of organisms', 'modern system for classifying organisms']
#
# 1.  data_input_text : causes of drugs and alcohol
# 2.  data_input_text : causes of drugs and alcohol
# 1.  lbl2data_input_text : ['drugs', 'alcohol', 'drugs', 'alcohol']
# 2.  lbl2data_input_text : ['alcohol', 'drugs', 'drug', 'alcohol drinks', 'causes']
#
# 1.  data_input_text : calorie of granola bar
# 2.  data_input_text : calorie of granola bar
# 1.  lbl2data_input_text : ['calorie', 'granola bar']
# 2.  lbl2data_input_text : ['granola', 'calorie', 'granola bars', 'granola bar', 'sunbelt granola bar']
#
# 1.  data_input_text : what does draw weight mean archery
# 2.  data_input_text : what does draw weight mean archery
# 1.  lbl2data_input_text : ['draw weight', 'archery']
# 2.  lbl2data_input_text : ['weight', 'archery season', 'archery', 'draw weight', 'archery instructor']
#
# 1.  data_input_text : what is the ops stat for baseball
# 2.  data_input_text : what is the ops stat for baseball
# 1.  lbl2data_input_text : ['ops', 'baseball']
# 2.  lbl2data_input_text : ['baseball', 'mlb', 'ops', 'opsin', 'stat']
#
# 1.  data_input_text : actress who plays alice on the magicians
# 2.  data_input_text : actress who plays alice on the magicians
# 1.  lbl2data_input_text : ['alice', 'the magicians']
# 2.  lbl2data_input_text : ['alice', 'alice in wonderland', 'magician', 'the magician', 'the magicians']
#
# 1.  data_input_text : can cuisinart electric pressure cooker be used as a canner
# 2.  data_input_text : can cuisinart electric pressure cooker be used as a canner
# 1.  lbl2data_input_text : ['cuisinart', 'electric pressure cooker', 'canner']
# 2.  lbl2data_input_text : ['pressure cooker', 'electric pressure cooker', 'cuisinart', 'electric cooker', 'pressure canner']
#
# 1.  data_input_text : what cleans your liver and kidneys
# 2.  data_input_text : what cleans your liver and kidneys
# 1.  lbl2data_input_text : ['vitamin d', 'hip pain', 'mattress', 'spine', 'liver', 'kidneys', 'liver', 'kidneys']
# 2.  lbl2data_input_text : ['liver', 'kidneys', 'kidney', 'kidneys, ureters, and bladder', 'kidney transplants']
#
# 1.  data_input_text : what is the mayor of torrington ct salary
# 2.  data_input_text : what is the mayor of torrington ct salary
# 1.  lbl2data_input_text : ['torrington', 'ct', 'mayor']
# 2.  lbl2data_input_text : ['mayor', 'connecticut', 'torrington', 'farrington lake park', 'governor of connecticut']
#
# 1.  data_input_text : when will i start puberty quiz for girls
# 2.  data_input_text : when will i start puberty quiz for girls
# 1.  lbl2data_input_text : ['puberty', 'quiz', 'girls']
# 2.  lbl2data_input_text : ['puberty', 'girls', 'early puberty', 'precocious puberty', 'delayed puberty']
#
# 1.  data_input_text : how to convert voice recording to mp4 samsung galaxy
# 2.  data_input_text : how to convert voice recording to mp4 samsung galaxy
# 1.  lbl2data_input_text : ['samsung galaxy', 'mp4']
# 2.  lbl2data_input_text : ['samsung galaxy s4', 'samsung s4', 'mp4', 'samsung galaxy', 'samsung4']
#
# 1.  data_input_text : kindle account device serial number
# 2.  data_input_text : kindle account device serial number
# 1.  lbl2data_input_text : ['kindle', 'serial number']
# 2.  lbl2data_input_text : ['kindle', 'serial number', 'kindle app', 'kindle reader', 'kindle edition']
#
# 1.  data_input_text : define incision and drainage
# 2.  data_input_text : define incision and drainage
# 1.  lbl2data_input_text : ['incision', 'drainage']
# 2.  lbl2data_input_text : ['drainage system', 'incision', 'drainage', 'surgical incision', 'incision vasectomy']
#
# 1.  data_input_text : what is the purpose of a condenser on a car
# 2.  data_input_text : what is the purpose of a condenser on a car
# 1.  lbl2data_input_text : ['condenser', 'car', 'condenser', 'car']
# 2.  lbl2data_input_text : ['car', 'ac condenser', 'ignition condenser', 'condenser', 'the car']
#
# 1.  data_input_text : what year was metallica release their first album
# 2.  data_input_text : what year was metallica release their first album
# 1.  lbl2data_input_text : ['metallica', 'first album', 'metallica']
# 2.  lbl2data_input_text : ['metallica', 'the first american', 'first album', 'debut album', 'first released']
#
# 1.  data_input_text : what does ocr in hipaa mean
# 2.  data_input_text : what does ocr in hipaa mean
# 1.  lbl2data_input_text : ['vitamin d', 'ocr', 'hipaa']
# 2.  lbl2data_input_text : ['ocr', 'hipaa', 'hipaa law', 'apcr', 'oaa']
#
# 1.  data_input_text : what does in semper mean in latin
# 2.  data_input_text : what does in semper mean in latin
# 1.  lbl2data_input_text : ['semper', 'latin']
# 2.  lbl2data_input_text : ['latin', 'semper', 'vulgar latin', 'semper fidelis', 'semper fi']
#
# 1.  data_input_text : population of skagway alaska
# 2.  data_input_text : population of skagway alaska
# 1.  lbl2data_input_text : ['skagway', 'alaska']
# 2.  lbl2data_input_text : ['alaska', 'fairbanks, alaska', 'skagway', 'anchorage, alaska', 'ketchikan, alaska']
#
# 1.  data_input_text : what is a normal pulse rate for men uk
# 2.  data_input_text : what is a normal pulse rate for men uk
# 1.  lbl2data_input_text : ['pulse rate', 'men', 'uk']
# 2.  lbl2data_input_text : ['uk', 'pulse rate', 'britain', 'heart pulse rate', 'pulse rates']
#
# 1.  data_input_text : what does joe maddon use on his hair
# 2.  data_input_text : what does joe maddon use on his hair
# 1.  lbl2data_input_text : ['joe maddon', 'hair']
# 2.  lbl2data_input_text : ['hair', 'mad men', 'hair color', 'hair colour', 'joe maddon']
#
# 1.  data_input_text : what does led lcd tv
# 2.  data_input_text : what does led lcd tv
# 1.  lbl2data_input_text : ['led', 'lcd', 'tv', 'led', 'lcd', 'tv']
# 2.  lbl2data_input_text : ['led tv', 'led', 'lcd', 'lcd tv', 'lcd television']
#
# 1.  data_input_text : what's the difference between racquetball and squash
# 2.  data_input_text : what's the difference between racquetball and squash
# 1.  lbl2data_input_text : ['racquetball', 'squash']
# 2.  lbl2data_input_text : ['squash', 'racquetball', 'tennis racquet', 'tennis racquets', 'squashes']
#
# 1.  data_input_text : what does lh rh mean
# 2.  data_input_text : what does lh rh mean
# 1.  lbl2data_input_text : ['lh', 'rh']
# 2.  lbl2data_input_text : ['lh', 'rh blood type', 'rh', 'rh blood testing', 'rh- blood']
#
# 1.  data_input_text : what does lsa stand for in oil and gas
# 2.  data_input_text : what does lsa stand for in oil and gas
# 1.  lbl2data_input_text : ['lsa', 'oil and gas']
# 2.  lbl2data_input_text : ['lsa', 'lsac', 'oil and gas', 'oil and gas well', 'lsa recovery']
#
# 1.  data_input_text : what does mepa stand for in ma
# 2.  data_input_text : what does mepa stand for in ma
# 1.  lbl2data_input_text : ['mepa', 'ma']
# 2.  lbl2data_input_text : ['ma', 'boston, massachusetts', 'boston, ma', 'mepa', 'lowell, ma']
#
# 1.  data_input_text : what does monkey mean in china
# 2.  data_input_text : what does monkey mean in china
# 1.  lbl2data_input_text : ['monkey', 'china']
# 2.  lbl2data_input_text : ['china', 'monkey', 'chinese monkey king', "people's republic of china", 'republic of china']
#
# 1.  data_input_text : what countries held puerto rico
# 2.  data_input_text : what countries held puerto rico
# 1.  lbl2data_input_text : ['puerto rico', 'countries']
# 2.  lbl2data_input_text : ['puerto rico', 'countries', 'puerto rican', 'puerto ricans', 'san juan, puerto rico']
#
# 1.  data_input_text : benefits of coconut oil for gout
# 2.  data_input_text : benefits of coconut oil for gout
# 1.  lbl2data_input_text : ['coconut oil', 'gout']
# 2.  lbl2data_input_text : ['gout', 'coconut oil', 'coconut donut', 'organic coconut oil', 'gout pain']
#
# 1.  data_input_text : calories burned using elliptical
# 2.  data_input_text : calories burned using elliptical
# 1.  lbl2data_input_text : ['calories', 'elliptical']
# 2.  lbl2data_input_text : ['calories', 'elliptical', 'elliptical machines', 'empty calories', 'elliptical orbit']
#
# 1.  data_input_text : against what part of the electromagnetic spectrum does sunscreen protect?
# 2.  data_input_text : against what part of the electromagnetic spectrum does sunscreen protect?
# 1.  lbl2data_input_text : ['electromagnetic spectrum', 'sunscreen']
# 2.  lbl2data_input_text : ['sunscreen', 'electromagnetic spectrum', 'physical sunscreen', 'chemical sunscreen', 'electromagnetic radiation spectrum']
#
# 1.  data_input_text : how much is a sheet of plywood at lowe's
# 2.  data_input_text : how much is a sheet of plywood at lowe's
# 1.  lbl2data_input_text : ["lowe's", 'plywood']
# 2.  lbl2data_input_text : ['plywood', 'lowes', "lowe's", 'sheet of plywood', "lowe's companies, inc."]
#
# 1.  data_input_text : convert oz to gallons
# 2.  data_input_text : convert oz to gallons
# 1.  lbl2data_input_text : ['oz', 'gallons']
# 2.  lbl2data_input_text : ['1 oz', 'oz', 'gallons', 'u.s. gallons', 'oz.']
#
# 1.  data_input_text : can prozac cause nausea
# 2.  data_input_text : can prozac cause nausea
# 1.  lbl2data_input_text : ['prozac', 'nausea']
# 2.  lbl2data_input_text : ['nausea', 'prozac', 'tiazac', 'anti nausea medication', 'tazac']
#
# 1.  data_input_text : what is the simplest whole-number ratio of atoms in a molecule or formula unit called?
# 2.  data_input_text : what is the simplest whole-number ratio of atoms in a molecule or formula unit called?
# 1.  lbl2data_input_text : ['atoms', 'molecule']
# 2.  lbl2data_input_text : ['molecules', 'molecule', 'atoms', 'molecular formula', 'chemical formula']
#
# 1.  data_input_text : what county is edinboro pa in
# 2.  data_input_text : what county is edinboro pa in
# 1.  lbl2data_input_text : ['edinboro', 'pa', 'county']
# 2.  lbl2data_input_text : ['pa', 'franklin county, pennsylvania', 'cameron county, pa', 'washington, pa', 'edinboro']
#
# 1.  data_input_text : how much should a sow eat pounds per day
# 2.  data_input_text : how much should a sow eat pounds per day
# 1.  lbl2data_input_text : ['sow', 'pounds', 'day']
# 2.  lbl2data_input_text : ['pounds', 'hours per day', 'sow', 'per day', 'two meals a day']
#
# 1.  data_input_text : how much silver in sterling silver?
# 2.  data_input_text : how much silver in sterling silver?
# 1.  lbl2data_input_text : ['silver', 'sterling silver']
# 2.  lbl2data_input_text : ['sterling', 'silver', 'sterling silver', 'deep silver', '.925 sterling silver']
#
# 1.  data_input_text : is phentermine a amphetamines;
# 2.  data_input_text : is phentermine a amphetamines;
# 1.  lbl2data_input_text : ['phentermine', 'amphetamines', 'phentermine', 'amphetamines']
# 2.  lbl2data_input_text : ['phentermine', 'amphetamine salts', 'amphetamine', 'amphetamine-related disorders', 'amphetamines']
#
# 1.  data_input_text : is betadine and iodine the same
# 2.  data_input_text : is betadine and iodine the same
# 1.  lbl2data_input_text : ['betadine', 'iodine']
# 2.  lbl2data_input_text : ['iodine', 'iodine scan', 'radioactive iodine', 'betadine', 'iodine radiation']
#
# 1.  data_input_text : is lantus considered an insulin?
# 2.  data_input_text : is lantus considered an insulin?
# 1.  lbl2data_input_text : ['lantus', 'insulin']
# 2.  lbl2data_input_text : ['insulin', 'lantus pen', 'lantus', 'insulins', 'lantus insulin']
#
# 1.  data_input_text : how much square foot per child in a mn child care center
# 2.  data_input_text : how much square foot per child in a mn child care center
# 1.  lbl2data_input_text : ['square foot', 'child', 'mn', 'child care center']
# 2.  lbl2data_input_text : ['minnesota', 'mn', 'child care center', 'minneapolis, mn', 'child care resource center']
#
# 1.  data_input_text : lasik surgery how long to wear goggles at night
# 2.  data_input_text : lasik surgery how long to wear goggles at night
# 1.  lbl2data_input_text : ['lasik surgery', 'goggles']
# 2.  lbl2data_input_text : ['lasik', 'lasik eye surgery', 'lasik surgery', 'goggles', 'sunglasses at night']
#
# 1.  data_input_text : what vitamin deficiency causes mouth sores
# 2.  data_input_text : what vitamin deficiency causes mouth sores
# 1.  lbl2data_input_text : ['vitamin deficiency', 'mouth sores', 'vitamin deficiency', 'mouth sores']
# 2.  lbl2data_input_text : ['mouth sores', 'vitamin deficiency', 'mouth sore', 'sore mouth', 'sores in mouth']
#
# 1.  data_input_text : what gives the epa the authority to publish radiation protection guidance for other federal agencies
# 2.  data_input_text : what gives the epa the authority to publish radiation protection guidance for other federal agencies
# 1.  lbl2data_input_text : ['epa', 'federal agencies']
# 2.  lbl2data_input_text : ['epa', 'federal agency', 'federal agencies', 'radiation protection', 'us epa']
#
# 1.  data_input_text : definition of culture in an organization
# 2.  data_input_text : definition of culture in an organization
# 1.  lbl2data_input_text : ['culture', 'organization']
# 2.  lbl2data_input_text : ['organization', 'culture', 'organizations', 'organizational culture', 'organisation culture']
#
# 1.  data_input_text : nist definitions of private and community clouds
# 2.  data_input_text : nist definitions of private and community clouds
# 1.  lbl2data_input_text : ['nist', 'private cloud']
# 2.  lbl2data_input_text : ['nist', 'clouds', 'private', 'public cloud', 'private cloud']
#
# 1.  data_input_text : losartan side effects erectile dysfunction
# 2.  data_input_text : losartan side effects erectile dysfunction
# 1.  lbl2data_input_text : ['losartan', 'erectile dysfunction']
# 2.  lbl2data_input_text : ['erectile dysfunction', 'losartan', 'losartan potassium', 'losartan hctz', 'penile erectile dysfunction']
#
# 1.  data_input_text : can running strengthen back
# 2.  data_input_text : can running strengthen back
# 1.  lbl2data_input_text : ['running', 'back']
# 2.  lbl2data_input_text : ['running', 'running back', 'back', 'running backs', 'strained back']
#
# 1.  data_input_text : is cyclosporine an antibiotic
# 2.  data_input_text : is cyclosporine an antibiotic
# 1.  lbl2data_input_text : ['cyclosporine', 'antibiotic']
# 2.  lbl2data_input_text : ['antibiotic', 'antibiotic ointment', 'cyclosporine', 'tetracycline antibiotics', 'cyclospora']
#
# 1.  data_input_text : what has the study of fossils allowed scientist to do
# 2.  data_input_text : what has the study of fossils allowed scientist to do
# 1.  lbl2data_input_text : ['fossils', 'scientist']
# 2.  lbl2data_input_text : ['fossils', 'scientist', 'scientists', 'fossil', 'scientific study']
#
# 1.  data_input_text : what impact did world war ii have on the american economy?
# 2.  data_input_text : what impact did world war ii have on the american economy?
# 1.  lbl2data_input_text : ['world war ii', 'american economy']
# 2.  lbl2data_input_text : ['world war ii', 'war economy', 'economic impacts', 'american economy', 'economic impact']
#
# 1.  data_input_text : what is a windows batch file
# 2.  data_input_text : what is a windows batch file
# 1.  lbl2data_input_text : ['windows', 'batch file']
# 2.  lbl2data_input_text : ['windows', 'windows file protection', 'batch file', 'batch process', 'batch codes']
#
# 1.  data_input_text : what internet security do you get with rcn
# 2.  data_input_text : what internet security do you get with rcn
# 1.  lbl2data_input_text : ['rcn', 'internet security']
# 2.  lbl2data_input_text : ['internet security', 'rcn', 'us national security', 'computer security', 'internet safety']
#
# 1.  data_input_text : when was napoleon in holland?
# 2.  data_input_text : when was napoleon in holland?
# 1.  lbl2data_input_text : ['napoleon', 'holland']
# 2.  lbl2data_input_text : ['napoleon', 'holland', 'napoleon bonaparte', 'napoleon i', 'napoleon iii']
#
# 1.  data_input_text : when is the opening day of dove season in alabama
# 2.  data_input_text : when is the opening day of dove season in alabama
# 1.  lbl2data_input_text : ['dove season', 'alabama']
# 2.  lbl2data_input_text : ['alabama', 'dove season', 'birmingham, alabama', 'huntsville, alabama', 'state of alabama']
#
# 1.  data_input_text : what does the swastika symbol represent germany
# 2.  data_input_text : what does the swastika symbol represent germany
# 1.  lbl2data_input_text : ['swastika', 'germany', 'swastika', 'germany']
# 2.  lbl2data_input_text : ['germany', 'nazi germany', 'swastika', 'berlin, germany', 'socialist unity party of germany']
#
# 1.  data_input_text : is it normal to have heartburn during the first trimester pregnancy
# 2.  data_input_text : is it normal to have heartburn during the first trimester pregnancy
# 1.  lbl2data_input_text : ['heartburn', 'first trimester', 'pregnancy']
# 2.  lbl2data_input_text : ['trimester', 'heartburn', '1st trimester', 'first trimester', 'trimesters']
#
# 1.  data_input_text : what is a cabinet in govt
# 2.  data_input_text : what is a cabinet in govt
# 1.  lbl2data_input_text : ['cabinet', 'govt']
# 2.  lbl2data_input_text : ['cabinet', 'govt', 'presidential cabinet', 'us cabinet', 'political cabinets']
#
# 1.  data_input_text : what does cooper mean in england
# 2.  data_input_text : what does cooper mean in england
# 1.  lbl2data_input_text : ['cooper', 'england']
# 2.  lbl2data_input_text : ['uk', 'england', 'cooper county', 'england and wales', 'cooper']
#
# 1.  data_input_text : what county is charlottesville virginia
# 2.  data_input_text : what county is charlottesville virginia
# 1.  lbl2data_input_text : ['charlottesville', 'virginia']
# 2.  lbl2data_input_text : ['charlotte, nc', 'virginia', 'charlotte county', 'charlottesville', 'charlottesville, va']

# %%
idxs = np.argsort(np.ravel(metric.sum(axis=1)))[:100]
disp.show(idxs)
# Out:
# 1.  data_input_text : was hocus pocus filmed in salem
# 2.  data_input_text : was hocus pocus filmed in salem
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['salem', 'salem, oregon', 'salem, or', 'hocus pocus', 'salem, massachusetts']
#
# 1.  data_input_text : what beach is close to disneyland california
# 2.  data_input_text : what beach is close to disneyland california
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['disneyland', 'disneyland resort', 'venice beach, california', 'disneyland park', 'disneyland resort hotel']
#
# 1.  data_input_text : unemployment rate honolulu hawaii
# 2.  data_input_text : unemployment rate honolulu hawaii
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['hawaii', 'honolulu', 'honolulu county', 'downtown honolulu', 'honolulu, hi']
#
# 1.  data_input_text : what is guantanamo bay
# 2.  data_input_text : what is guantanamo bay
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['guantanamo bay prison', 'guantanamo bay', 'guantanamo detainees', 'guantanamo bay detention camp', 'guantanamo']
#
# 1.  data_input_text : what is facebook used for
# 2.  data_input_text : what is facebook used for
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['facebook', 'business facebook account', 'facebook live', 'facebook marketplace', 'facebook messenger']
#
# 1.  data_input_text : what is granicrete
# 2.  data_input_text : what is granicrete
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['accreta', 'beret', 'grans', 'grana', 'ristretto']
#
# 1.  data_input_text : what is chitosan good for
# 2.  data_input_text : what is chitosan good for
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['chitosan', 'cytoskeleton', 'chitin', 'chito', 'chitosanase']
#
# 1.  data_input_text : weather in nuremberg in august
# 2.  data_input_text : weather in nuremberg in august
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['august', 'august 2', 'august 1', 'nuremberg laws', 'nuremberg']
#
# 1.  data_input_text : how many 1000 in 1 million
# 2.  data_input_text : how many 1000 in 1 million
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['million', '1000', '100000', 'one million', 'one in a million']
#
# 1.  data_input_text : what is gabba
# 2.  data_input_text : what is gabba
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['the gabba', 'jabba', 'habba syndrome', 'sabbas', 'kabba']
#
# 1.  data_input_text : total number killed in civil war
# 2.  data_input_text : total number killed in civil war
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['civil war', 'u.s. civil war', 'us civil war', 'civil wars', 'battle of the civil war']
#
# 1.  data_input_text : tissue creep definition
# 2.  data_input_text : tissue creep definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['tissue', 'creep', 'tissue development', 'tissue repair', 'tissue growth']
#
# 1.  data_input_text : get rid of cellulite fast at home
# 2.  data_input_text : get rid of cellulite fast at home
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['home', 'cellulite', 'cellulitis', 'mobile home', 'radiculitis']
#
# 1.  data_input_text : monsters definition synonym
# 2.  data_input_text : monsters definition synonym
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['synonym', 'monsters', 'monsters, inc.', 'monster', 'synonyms']
#
# 1.  data_input_text : average income for north salem new york
# 2.  data_input_text : average income for north salem new york
# 1.  lbl2data_input_text : ['new york']
# 2.  lbl2data_input_text : ['salem', 'salem, or', 'new salem', 'north salem, ny', 'town of salem']
#
# 1.  data_input_text : what is dynamic resolution
# 2.  data_input_text : what is dynamic resolution
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['resolution', 'dynamic equilibrium', 'dynamic super resolution', 'dynamic tension', 'dynamic']
#
# 1.  data_input_text : side effects of baytril injections in dogs
# 2.  data_input_text : side effects of baytril injections in dogs
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['dogs', 'side effects', 'side effect', 'baytril', 'baytril otic']
#
# 1.  data_input_text : what are the main of functions of the skin
# 2.  data_input_text : what are the main of functions of the skin
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['skin', 'skin color', 'functions', 'body functions', 'skin colour']
#
# 1.  data_input_text : hippo denotation definition
# 2.  data_input_text : hippo denotation definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['hippos', 'denotation', 'hippo', 'baby hippos', 'pygmy hippos']
#
# 1.  data_input_text : how much should you save per month
# 2.  data_input_text : how much should you save per month
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['month', 'one month', 'price per month', '1 month', 'month to month']
#
# 1.  data_input_text : what are prime costs
# 2.  data_input_text : what are prime costs
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['prime rate', 'prime cost', 'prime', 'prime time', 'prime numbers']
#
# 1.  data_input_text : how to make your chocolate protein shake taste better
# 2.  data_input_text : how to make your chocolate protein shake taste better
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['protein shake', 'protein shakes', 'shake and bake', 'chocolate shakeology', 'chocolate shake']
#
# 1.  data_input_text : what is causing green slim on bowel movements
# 2.  data_input_text : what is causing green slim on bowel movements
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['bowel movements', 'green bowel movements', 'yellow bowel movement', 'bowel movement', 'irregular bowel movements']
#
# 1.  data_input_text : pottawatomie massacre quizlet
# 2.  data_input_text : pottawatomie massacre quizlet
# 1.  lbl2data_input_text : ['quizlet']
# 2.  lbl2data_input_text : ['chumash massacre', 'chainsaw massacre', 'potawatomi', 'waxhaw massacre', 'massacre']
#
# 1.  data_input_text : what is a legal fiction
# 2.  data_input_text : what is a legal fiction
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['historical fiction', 'fiction', 'legal definition', 'work of fiction', 'literary fiction']
#
# 1.  data_input_text : definition of vit
# 2.  data_input_text : definition of vit
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['vi', 'vig', 'vit hits', 'vit d', 'vid']
#
# 1.  data_input_text : what are oil pastels used for
# 2.  data_input_text : what are oil pastels used for
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['pastena', 'oil pastels', 'pastels', 'pastel colors', 'pastel color']
#
# 1.  data_input_text : what is a millennium baby
# 2.  data_input_text : what is a millennium baby
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['baby', 'millennium', 'millennium stadium', 'millennium, inc.', 'millennium babies']
#
# 1.  data_input_text : is rensselaer polytechnic institute
# 2.  data_input_text : is rensselaer polytechnic institute
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['rensselaer, indiana', 'rensselaer', 'albany institute of history & art', 'rensselaer county', 'traer']
#
# 1.  data_input_text : what is chattahoochee
# 2.  data_input_text : what is chattahoochee
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['chattahoochee hills', 'chattahoochee', 'chattahoochee river', 'chattahoochee tech', 'trochee']
#
# 1.  data_input_text : reference cells in excel
# 2.  data_input_text : reference cells in excel
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['excel', 'microsoft excel', 'cell references', 'cell reference', 'excel development']
#
# 1.  data_input_text : define: entity's
# 2.  data_input_text : define: entity's
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['entity', 'entity1', 'entityn', 'entity code', 'entities']
#
# 1.  data_input_text : what is fasting before blood test
# 2.  data_input_text : what is fasting before blood test
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['blood test', 'fasting labs', 'fasting', 'fasting blood test', 'fasting blood work']
#
# 1.  data_input_text : what are comps?
# 2.  data_input_text : what are comps?
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['usps', 'workers comp', 'comp cams', "workers' comp", 'comp coverage']
#
# 1.  data_input_text : what are the ingredients in stemuderm
# 2.  data_input_text : what are the ingredients in stemuderm
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['stemi', 'stem', 'stem gall', 'stemcell technologies', 'stemco']
#
# 1.  data_input_text : synthesis literary definition ex
# 2.  data_input_text : synthesis literary definition ex
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['synthesis reaction', 'synthesis', 'modern synthesis', 'literary', 'synthesis chemical reaction']
#
# 1.  data_input_text : how old should a baby be able to clap
# 2.  data_input_text : how old should a baby be able to clap
# 1.  lbl2data_input_text : ['baby']
# 2.  lbl2data_input_text : ['hand clap', 'one year old baby', 'the clap', 'claps', 'clap']
#
# 1.  data_input_text : what is considered an average iq
# 2.  data_input_text : what is considered an average iq
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['iq', 'iq score', 'average', 'iqs', 'iq tests']
#
# 1.  data_input_text : definition for daring
# 2.  data_input_text : definition for daring
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['definition', 'meanings', 'meaning', 'define', 'bravery']
#
# 1.  data_input_text : zarxio what is this medication use
# 2.  data_input_text : zarxio what is this medication use
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['zara', 'zar', 'zari', 'zarxio', 'roxio']
#
# 1.  data_input_text : definition of western european time zone
# 2.  data_input_text : definition of western european time zone
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['time zone', 'western europe', 'western european time zone', 'eastern european time', 'western european']
#
# 1.  data_input_text : what does contract and expand mean
# 2.  data_input_text : what does contract and expand mean
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['contract', 'contracts', 'types of contracts', 'expansion', 'contract job']
#
# 1.  data_input_text : media definition examples
# 2.  data_input_text : media definition examples
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['definition', 'media', 'example', 'define', 'examples']
#
# 1.  data_input_text : types of standards for frequency generators
# 2.  data_input_text : types of standards for frequency generators
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['frequency', 'generator', 'generators', 'frequency modulation', 'frequencies']
#
# 1.  data_input_text : what is dynamics
# 2.  data_input_text : what is dynamics
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['dynamics crm', 'general dynamics', 'dynamics ax', 'dynamics', 'microsoft dynamics']
#
# 1.  data_input_text : what are overpacks used for in hazardous material
# 2.  data_input_text : what are overpacks used for in hazardous material
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['hazardous material', 'wolfpack', 'hazardous materials technician', 'hazardous materials', 'hazardous foods']
#
# 1.  data_input_text : monoxide poisoning symptoms
# 2.  data_input_text : monoxide poisoning symptoms
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['carbon monoxide', 'carbon monoxide poisoning', 'dihydrogen monoxide', 'dihydrate monoxide', 'dichloro monoxide']
#
# 1.  data_input_text : dcu routing number'
# 2.  data_input_text : dcu routing number'
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['dc', 'dcc', 'dco', 'dcn', 'angle dcu']
#
# 1.  data_input_text : how old can a baby get its first hair
# 2.  data_input_text : how old can a baby get its first hair
# 1.  lbl2data_input_text : ['baby']
# 2.  lbl2data_input_text : ['hair', 'one year old baby', 'long hair', 'body hair', 'baby hair']
#
# 1.  data_input_text : temperature sensors - analog output
# 2.  data_input_text : temperature sensors - analog output
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['analog', 'analog signals', 'temperature sensor', 'sensors', 'ambient temperature sensor']
#
# 1.  data_input_text : what channel is univision?
# 2.  data_input_text : what channel is univision?
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['channel', 'activision', 'univision tejano', 'a channel', 'television channel']
#
# 1.  data_input_text : how many babies in a chipmunk birth?
# 2.  data_input_text : how many babies in a chipmunk birth?
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['babies', 'chipmunks', 'alvin and the chipmunks', 'baby chipmunks', 'chipmunk']
#
# 1.  data_input_text : what are the delta comfort seats
# 2.  data_input_text : what are the delta comfort seats
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['delta', 'delta flights', 'delta pilots', 'delta airlines', 'delta air']
#
# 1.  data_input_text : what is crossfit?
# 2.  data_input_text : what is crossfit?
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['crossfit', 'anytime crossfit', 'crossfit games', 'enfit', 'crossfitters']
#
# 1.  data_input_text : what is generation x?
# 2.  data_input_text : what is generation x?
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['generation y', 'generation', 'generation x', 'generation xers', 'x generation']
#
# 1.  data_input_text : what is headlock elite supplement
# 2.  data_input_text : what is headlock elite supplement
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['supplement', 'the elite', 'elite', 'headlock muscle booster', 'power elite']
#
# 1.  data_input_text : umeclidinium cost
# 2.  data_input_text : umeclidinium cost
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['cost', 'condominium', 'aclidinium bromide', 'umeclidinium', 'condominiums']
#
# 1.  data_input_text : should patient medical records be private
# 2.  data_input_text : should patient medical records be private
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['medical records', 'patient records', 'private', 'personal medical record', 'health records']
#
# 1.  data_input_text : what does nasa say about why we have moon phases
# 2.  data_input_text : what does nasa say about why we have moon phases
# 1.  lbl2data_input_text : ['nasa', 'moon', 'vitamin d', 'mg']
# 2.  lbl2data_input_text : ['moon phases', 'moon phase', 'lunar phases', 'phases of the moon', 'phase of the moon']
#
# 1.  data_input_text : what are perennial
# 2.  data_input_text : what are perennial
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['perennials', 'perennial', 'perennial plant', 'perennial plants', 'perennial flowers']
#
# 1.  data_input_text : rwa definition
# 2.  data_input_text : rwa definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['dwa', 'lwa', 'twa', 'rwa', 'rswa']
#
# 1.  data_input_text : population of paducah tx
# 2.  data_input_text : population of paducah tx
# 1.  lbl2data_input_text : ['tx']
# 2.  lbl2data_input_text : ['texas', 'duke of paducah', 'paducah, ky', 'bedford, texas', 'paducah, kentucky']
#
# 1.  data_input_text : what is a straddle
# 2.  data_input_text : what is a straddle
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['griddle', 'spindle', 'straddle', 'stradbroke island', 'stoddard']
#
# 1.  data_input_text : interquartile math definition
# 2.  data_input_text : interquartile math definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['math', 'interquartile range', 'maths', 'mathematical definition', 'interquartile']
#
# 1.  data_input_text : difference between coating and laminating
# 2.  data_input_text : difference between coating and laminating
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['laminate', 'lamination', 'resin laminating', 'coating', 'laminated flooring']
#
# 1.  data_input_text : definition: iterative
# 2.  data_input_text : definition: iterative
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['definition', 'degenerative disease', 'meaning', 'define', 'degenerative process']
#
# 1.  data_input_text : was killed in the philippines, but his ships were the first to circumnavigate the globe
# 2.  data_input_text : was killed in the philippines, but his ships were the first to circumnavigate the globe
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['philippines', 'globe', 'manila', 'philippine flag', 'president of the philippines']
#
# 1.  data_input_text : tila-respa integrated disclosure definition
# 2.  data_input_text : tila-respa integrated disclosure definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['metallica', 'respa', 'til', 'tila', 'tilo']
#
# 1.  data_input_text : how old is elly tran ha
# 2.  data_input_text : how old is elly tran ha
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['one-year-old', 'trane', '15-16 years old', 'years old', 'chris tran']
#
# 1.  data_input_text : what is coalescing material
# 2.  data_input_text : what is coalescing material
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['coal', 'material', 'materials', 'flooring materials', 'material cause']
#
# 1.  data_input_text : what is decon on nfl uniforms
# 2.  data_input_text : what is decon on nfl uniforms
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['nfl', 'nfl draft', 'nfl players', 'nfl season', 'nfl player']
#
# 1.  data_input_text : types organizational structure
# 2.  data_input_text : types organizational structure
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['organizational structure', 'structure', 'organizational', 'business structure', 'corporate structure']
#
# 1.  data_input_text : what is drang und sturm?
# 2.  data_input_text : what is drang und sturm?
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['dro', 'germ', 'stun', 'sepang', 'therm']
#
# 1.  data_input_text : population of antigonish
# 2.  data_input_text : population of antigonish
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['population', 'antigone', 'populations', 'algonquin peoples', 'population census']
#
# 1.  data_input_text : how many carbs in a quest bar
# 2.  data_input_text : how many carbs in a quest bar
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['carbs', 'carb', 'quest nutrition', 'quest', 'quest plus']
#
# 1.  data_input_text : rex rabbit breed history
# 2.  data_input_text : rex rabbit breed history
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['rabbit', 'dwarf rex rabbits', 'rex', 'rex trailer', 'rex tucker']
#
# 1.  data_input_text : how much are virgin america change fees
# 2.  data_input_text : how much are virgin america change fees
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['u.s. virgin islands', 'change fee', 'virgin america', 'flight change fee', 'virgin money']
#
# 1.  data_input_text : what is donald trump a draft dodger
# 2.  data_input_text : what is donald trump a draft dodger
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['donald trump', 'trump', 'president trump', 'donald j trump', 'dodger']
#
# 1.  data_input_text : two rivers supervisory union
# 2.  data_input_text : two rivers supervisory union
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['union', 'rivers', 'river region credit union', 'unions', 'two rivers']
#
# 1.  data_input_text : symptoms of hypocalcemia
# 2.  data_input_text : symptoms of hypocalcemia
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['hypoglycemia', 'hypophosphatemia', 'hypothermia', 'hypocalcemia', 'hypochloremia']
#
# 1.  data_input_text : vanda orchids different leaf types
# 2.  data_input_text : vanda orchids different leaf types
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['orchid', 'orchids', 'vanda flowers', 'candida species', 'orchid plants']
#
# 1.  data_input_text : what is dendrochronology
# 2.  data_input_text : what is dendrochronology
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['geochronology', 'denon', 'dendrogram', 'dendrochronology', 'denodo']
#
# 1.  data_input_text : how many calories in a medium smoothie king smoothie
# 2.  data_input_text : how many calories in a medium smoothie king smoothie
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['calories', 'smoothie', 'smoothie king center', 'mixed fruit smoothie', 'smoothies']
#
# 1.  data_input_text : definition restricting
# 2.  data_input_text : definition restricting
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['definition', 'meaning', 'restrictions', 'define', 'legal definition']
#
# 1.  data_input_text : share of cost
# 2.  data_input_text : share of cost
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['share price', 'share', 'cost sharing', 'price per share', 'retail cost sharing']
#
# 1.  data_input_text : what is florida villa
# 2.  data_input_text : what is florida villa
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['florida', 'private villa', 'lake villa', 'villa', 'plantation, florida']
#
# 1.  data_input_text : highest salary ronaldo
# 2.  data_input_text : highest salary ronaldo
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['ronaldo', 'cristiano ronaldo', 'ronald', 'highest paid', 'ronaldo cristiano']
#
# 1.  data_input_text : types of business entities
# 2.  data_input_text : types of business entities
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['business entity concept', 'business entity tax', 'business entity', 'business entities', 'entities']
#
# 1.  data_input_text : the consent of how many state legislatures are needed to approve an amendment to the us constitution?
# 2.  data_input_text : the consent of how many state legislatures are needed to approve an amendment to the us constitution?
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['u.s. constitution', 'us constitution', 'united states constitution', 'constitution of the united states', 'states constitution']
#
# 1.  data_input_text : what causes low pressure on a pump for well water
# 2.  data_input_text : what causes low pressure on a pump for well water
# 1.  lbl2data_input_text : ['pump', 'well water']
# 2.  lbl2data_input_text : ['well pump', 'well pump valve', 'low pressure', 'shallow well pumps', 'well pumps']
#
# 1.  data_input_text : what is evidence discovery
# 2.  data_input_text : what is evidence discovery
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['discovery', 'evidence', 'u.s.s. discovery', 'investigation discovery', 'e-discovery']
#
# 1.  data_input_text : what cable connects pcs to printers
# 2.  data_input_text : what cable connects pcs to printers
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['printers', 'printer cable', 'pcs', 'printer usb cables', 'computer printer']
#
# 1.  data_input_text : what is employer sponsored insurance
# 2.  data_input_text : what is employer sponsored insurance
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['employer', 'insurance', 'employers', 'employer liability coverage', 'employee health insurance']
#
# 1.  data_input_text : stepford wife definition
# 2.  data_input_text : stepford wife definition
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['wife', 'rockford', 'rockford, il', 'seaford', 'steph']
#
# 1.  data_input_text : ryan gosling how tall
# 2.  data_input_text : ryan gosling how tall
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['ryan', 'ryan gosling', 'gosling', 'ryan fitzpatrick', 'goslings']
#
# 1.  data_input_text : what cause gi problems
# 2.  data_input_text : what cause gi problems
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['gis', 'gi', 'gi infection', 'gi testing', 'gi issues']
#
# 1.  data_input_text : what is haile selassie famous for
# 2.  data_input_text : what is haile selassie famous for
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['hail', 'molasses', 'haily', 'matelasse', 'molassas']
#
# 1.  data_input_text : what is cec on soil test
# 2.  data_input_text : what is cec on soil test
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['cecs', 'cea test', 'cec', 'cea testing', 'soil test']
#
# 1.  data_input_text : what are year quarters
# 2.  data_input_text : what are year quarters
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['us quarters', 'quarters', 'calendar quarters', 'winter quarters', 'roll of quarters']
#
# 1.  data_input_text : washington state mortgage rates
# 2.  data_input_text : washington state mortgage rates
# 1.  lbl2data_input_text : []
# 2.  lbl2data_input_text : ['washington', 'washington state', 'mortgage rates', 'washington state university', 'state of washington']

# %% [markdown]
# ## Conflation

# %%
from xcai.graph.operations import *
import matplotlib.pyplot as plt

# %%
data_dir = '/home/scai/phd/aiz218323/scratch/outputs/mogicX/01-msmarco-llama-entity-linker-002/predictions/'

trn_preds = sp.load_npz(f'{data_dir}/train_predictions_full.npz')
tst_preds = sp.load_npz(f'{data_dir}/test_predictions_full.npz')

# %%
trn_preds = retain_topk(trn_preds, k=10)
tst_preds = retain_topk(tst_preds, k=10)

# %%
tst_preds = sp.load_npz(f'{data_dir}/test_predictions_full.npz')
tst_preds = retain_topk(tst_preds, k=3)

# %% [markdown]
# ### Random walk

# %%
preds = Graph.threshold_on_degree(tst_preds.transpose().tocsr(), thresh=5)
preds = preds.transpose().tocsr()

# %%
rnd_tst_pred = Graph.random_walk(preds.transpose().tocsr(), walk_to=2, batch_size=1024, prob_reset=0.8, n_hops=2)
# Out:
#   0%|          | 0/196 [00:00<?, ?it/s]

# %%
sp.save_npz(f'{data_dir}/random_walk_train_predictions.npz', rnd_tst_pred)

# %% [markdown]
# ### Connected components

# %%
rnd_trn_lbl = sp.load_npz(f'{data_dir}/random_walk_train_predictions.npz')

# %%
n_comp, labels = connected_components(rnd_tst_pred, directed=False, return_labels=True)

components = {}
for lbl,txt in zip(labels,linker_block.train.dset.data.lbl_info['input_text']):
    components.setdefault(lbl, []).append(txt)

# %%
n_lbl = 100
colors = list(COLORS.keys())
colors = [colors[i] for i in np.random.permutation(len(colors))]

# %%
group_lengths = np.array([len(components[i]) for i in range(len(components))])

# %%
idxs = np.argsort(group_lengths)[:-n_lbl]

# %%
idxs = np.logical_and(group_lengths > 2, group_lengths < 6)

# %%
idxs = np.random.permutation(len(components))[:n_lbl]

# %%
for i,idx in enumerate(idxs):
    if i % 2 == 0: print(colored(f'{idx+1}. {" || ".join(components[idx])}', colors[i % len(colors)]))
    else: print(colored(f'{idx+1}. {" || ".join(components[idx])}', colors[i % len(colors)], attrs=["reverse", "blink"]))
# Out:
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# ...
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 2. justice || united states department of justice
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# 1. manhattan project
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
